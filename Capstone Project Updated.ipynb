# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn.pipeline import make_pipeline
from sklearn.impute import KNNImputer
from sklearn.preprocessing import RobustScaler,StandardScaler
from sklearn.model_selection import train_test_split,KFold,GridSearchCV,cross_val_score

from sklearn.linear_model import LinearRegression,ElasticNetCV, LassoCV, RidgeCV
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,ExtraTreesClassifier
from sklearn.svm import SVR
from lightgbm import LGBMRegressor
from mlxtend.regressor import StackingCVRegressor

from statistics import mean,median,mode
from scipy import stats
from scipy.stats import norm,skew,spearmanr
from sklearn.metrics import mean_squared_error
from scipy.special import boxcox1p
pd.set_option('display.max_columns', None)  
pd.set_option('display.max_rows', None) 
import random

# %%
df = pd.read_csv(r'C:\Users\Vishwarath Patil\Downloads\microsoft-data-science-capstone\training_values.csv')

# %%
label = pd.read_csv(r'C:\Users\Vishwarath Patil\Downloads\microsoft-data-science-capstone\training_labels.csv')

# %%
label.drop('row_id',axis=1,inplace=True)

# %%
df = pd.concat([df,label],axis=1)
df.drop('row_id',axis=1,inplace=True)
df.shape
# Out:
# (3198, 34)

# %%
df.isnull().sum()
# Out:
# area__rucc                                             0
# area__urban_influence                                  0
# econ__economic_typology                                0
# econ__pct_civilian_labor                               0
# econ__pct_unemployment                                 0
# econ__pct_uninsured_adults                             2
# econ__pct_uninsured_children                           2
# demo__pct_female                                       2
# demo__pct_below_18_years_of_age                        2
# demo__pct_aged_65_years_and_older                      2
# demo__pct_hispanic                                     2
# demo__pct_non_hispanic_african_american                2
# demo__pct_non_hispanic_white                           2
# demo__pct_american_indian_or_alaskan_native            2
# demo__pct_asian                                        2
# demo__pct_adults_less_than_a_high_school_diploma       0
# demo__pct_adults_with_high_school_diploma              0
# demo__pct_adults_with_some_college                     0
# demo__pct_adults_bachelors_or_higher                   0
# demo__birth_rate_per_1k                                0
# demo__death_rate_per_1k                                0
# health__pct_adult_obesity                              2
# health__pct_adult_smoking                            464
# health__pct_diabetes                                   2
# health__pct_low_birthweight                          182
# health__pct_excessive_drinking                       978
# health__pct_physical_inacticity                        2
# health__air_pollution_particulate_matter              28
# health__homicides_per_100k                          1967
# health__motor_vehicle_crash_deaths_per_100k          417
# health__pop_per_dentist                              244
# health__pop_per_primary_care_physician               230
# yr                                                     0
# heart_disease_mortality_per_100k                       0
# dtype: int64

# %%
df.corr()
# Out:
#                                                   econ__pct_civilian_labor  \
# econ__pct_civilian_labor                                          1.000000
# econ__pct_unemployment                                           -0.619050
# econ__pct_uninsured_adults                                       -0.409084
# econ__pct_uninsured_children                                     -0.027494
# demo__pct_female                                                  0.110016
# demo__pct_below_18_years_of_age                                  -0.014214
# demo__pct_aged_65_years_and_older                                 0.005105
# demo__pct_hispanic                                                0.006413
# demo__pct_non_hispanic_african_american                          -0.344771
# demo__pct_non_hispanic_white                                      0.272709
# demo__pct_american_indian_or_alaskan_native                      -0.135591
# demo__pct_asian                                                   0.177972
# demo__pct_adults_less_than_a_high_school_diploma                 -0.520928
# demo__pct_adults_with_high_school_diploma                        -0.221864
# demo__pct_adults_with_some_college                                0.239878
# demo__pct_adults_bachelors_or_higher                              0.432600
# demo__birth_rate_per_1k                                          -0.004480
# demo__death_rate_per_1k                                          -0.280318
# health__pct_adult_obesity                                        -0.370449
# health__pct_adult_smoking                                        -0.432774
# health__pct_diabetes                                             -0.501138
# health__pct_low_birthweight                                      -0.438661
# health__pct_excessive_drinking                                    0.387857
# health__pct_physical_inacticity                                  -0.346026
# health__air_pollution_particulate_matter                         -0.117639
# health__homicides_per_100k                                       -0.391567
# health__motor_vehicle_crash_deaths_per_100k                      -0.346759
# health__pop_per_dentist                                          -0.285938
# health__pop_per_primary_care_physician                           -0.218591
# heart_disease_mortality_per_100k                                 -0.476644
#
#                                                   econ__pct_unemployment  \
# econ__pct_civilian_labor                                       -0.619050
# econ__pct_unemployment                                          1.000000
# econ__pct_uninsured_adults                                      0.272174
# econ__pct_uninsured_children                                   -0.104250
# demo__pct_female                                                0.071061
# demo__pct_below_18_years_of_age                                 0.004807
# demo__pct_aged_65_years_and_older                              -0.049590
# demo__pct_hispanic                                             -0.023614
# demo__pct_non_hispanic_african_american                         0.382720
# demo__pct_non_hispanic_white                                   -0.318868
# demo__pct_american_indian_or_alaskan_native                     0.190529
# demo__pct_asian                                                -0.088859
# demo__pct_adults_less_than_a_high_school_diploma                0.417660
# demo__pct_adults_with_high_school_diploma                       0.188042
# demo__pct_adults_with_some_college                             -0.236731
# demo__pct_adults_bachelors_or_higher                           -0.328854
# demo__birth_rate_per_1k                                        -0.012124
# demo__death_rate_per_1k                                         0.190105
# health__pct_adult_obesity                                       0.292533
# health__pct_adult_smoking                                       0.357539
# health__pct_diabetes                                            0.421372
# health__pct_low_birthweight                                     0.378766
# health__pct_excessive_drinking                                 -0.214149
# health__pct_physical_inacticity                                 0.230216
# health__air_pollution_particulate_matter                        0.150009
# health__homicides_per_100k                                      0.418517
# health__motor_vehicle_crash_deaths_per_100k                     0.229797
# health__pop_per_dentist                                         0.178324
# health__pop_per_primary_care_physician                          0.136225
# heart_disease_mortality_per_100k                                0.371620
#
#                                                   econ__pct_uninsured_adults  \
# econ__pct_civilian_labor                                           -0.409084
# econ__pct_unemployment                                              0.272174
# econ__pct_uninsured_adults                                          1.000000
# econ__pct_uninsured_children                                        0.717686
# demo__pct_female                                                   -0.075923
# demo__pct_below_18_years_of_age                                     0.280156
# demo__pct_aged_65_years_and_older                                  -0.075758
# demo__pct_hispanic                                                  0.477905
# demo__pct_non_hispanic_african_american                             0.206069
# demo__pct_non_hispanic_white                                       -0.553043
# demo__pct_american_indian_or_alaskan_native                         0.244569
# demo__pct_asian                                                    -0.107385
# demo__pct_adults_less_than_a_high_school_diploma                    0.663280
# demo__pct_adults_with_high_school_diploma                           0.029720
# demo__pct_adults_with_some_college                                 -0.235539
# demo__pct_adults_bachelors_or_higher                               -0.391967
# demo__birth_rate_per_1k                                             0.283840
# demo__death_rate_per_1k                                             0.060668
# health__pct_adult_obesity                                           0.180362
# health__pct_adult_smoking                                           0.264521
# health__pct_diabetes                                                0.294417
# health__pct_low_birthweight                                         0.327780
# health__pct_excessive_drinking                                     -0.340959
# health__pct_physical_inacticity                                     0.285383
# health__air_pollution_particulate_matter                           -0.219350
# health__homicides_per_100k                                          0.410288
# health__motor_vehicle_crash_deaths_per_100k                         0.455132
# health__pop_per_dentist                                             0.237915
# health__pop_per_primary_care_physician                              0.165261
# heart_disease_mortality_per_100k                                    0.334217
#
#                                                   econ__pct_uninsured_children  \
# econ__pct_civilian_labor                                             -0.027494
# econ__pct_unemployment                                               -0.104250
# econ__pct_uninsured_adults                                            0.717686
# econ__pct_uninsured_children                                          1.000000
# demo__pct_female                                                     -0.210481
# demo__pct_below_18_years_of_age                                       0.183530
# demo__pct_aged_65_years_and_older                                     0.083595
# demo__pct_hispanic                                                    0.441586
# demo__pct_non_hispanic_african_american                              -0.102605
# demo__pct_non_hispanic_white                                         -0.296403
# demo__pct_american_indian_or_alaskan_native                           0.203009
# demo__pct_asian                                                      -0.088984
# demo__pct_adults_less_than_a_high_school_diploma                      0.281981
# demo__pct_adults_with_high_school_diploma                            -0.079490
# demo__pct_adults_with_some_college                                    0.040217
# demo__pct_adults_bachelors_or_higher                                 -0.176100
# demo__birth_rate_per_1k                                               0.161277
# demo__death_rate_per_1k                                              -0.049375
# health__pct_adult_obesity                                            -0.128264
# health__pct_adult_smoking                                             0.005351
# health__pct_diabetes                                                 -0.055636
# health__pct_low_birthweight                                           0.023666
# health__pct_excessive_drinking                                       -0.045826
# health__pct_physical_inacticity                                       0.009911
# health__air_pollution_particulate_matter                             -0.345746
# health__homicides_per_100k                                            0.109011
# health__motor_vehicle_crash_deaths_per_100k                           0.406176
# health__pop_per_dentist                                               0.152708
# health__pop_per_primary_care_physician                                0.103520
# heart_disease_mortality_per_100k                                     -0.034482
#
#                                                   demo__pct_female  \
# econ__pct_civilian_labor                                  0.110016
# econ__pct_unemployment                                    0.071061
# econ__pct_uninsured_adults                               -0.075923
# econ__pct_uninsured_children                             -0.210481
# demo__pct_female                                          1.000000
# demo__pct_below_18_years_of_age                           0.198426
# demo__pct_aged_65_years_and_older                         0.106818
# demo__pct_hispanic                                       -0.161775
# demo__pct_non_hispanic_african_american                   0.098055
# demo__pct_non_hispanic_white                              0.066155
# demo__pct_american_indian_or_alaskan_native              -0.067177
# demo__pct_asian                                           0.011124
# demo__pct_adults_less_than_a_high_school_diploma         -0.132861
# demo__pct_adults_with_high_school_diploma                -0.105611
# demo__pct_adults_with_some_college                        0.011703
# demo__pct_adults_bachelors_or_higher                      0.178108
# demo__birth_rate_per_1k                                   0.105928
# demo__death_rate_per_1k                                   0.183712
# health__pct_adult_obesity                                 0.042139
# health__pct_adult_smoking                                -0.061542
# health__pct_diabetes                                      0.189265
# health__pct_low_birthweight                               0.074387
# health__pct_excessive_drinking                           -0.215347
# health__pct_physical_inacticity                           0.068177
# health__air_pollution_particulate_matter                  0.109214
# health__homicides_per_100k                                0.150494
# health__motor_vehicle_crash_deaths_per_100k              -0.078898
# health__pop_per_dentist                                  -0.131156
# health__pop_per_primary_care_physician                   -0.131682
# heart_disease_mortality_per_100k                          0.087040
#
#                                                   demo__pct_below_18_years_of_age  \
# econ__pct_civilian_labor                                                -0.014214
# econ__pct_unemployment                                                   0.004807
# econ__pct_uninsured_adults                                               0.280156
# econ__pct_uninsured_children                                             0.183530
# demo__pct_female                                                         0.198426
# demo__pct_below_18_years_of_age                                          1.000000
# demo__pct_aged_65_years_and_older                                       -0.566433
# demo__pct_hispanic                                                       0.320619
# demo__pct_non_hispanic_african_american                                  0.021930
# demo__pct_non_hispanic_white                                            -0.372009
# demo__pct_american_indian_or_alaskan_native                              0.338919
# demo__pct_asian                                                          0.017484
# demo__pct_adults_less_than_a_high_school_diploma                         0.220713
# demo__pct_adults_with_high_school_diploma                               -0.115838
# demo__pct_adults_with_some_college                                       0.043561
# demo__pct_adults_bachelors_or_higher                                    -0.102530
# demo__birth_rate_per_1k                                                  0.729499
# demo__death_rate_per_1k                                                 -0.300698
# health__pct_adult_obesity                                                0.170959
# health__pct_adult_smoking                                               -0.001050
# health__pct_diabetes                                                    -0.039540
# health__pct_low_birthweight                                             -0.034874
# health__pct_excessive_drinking                                          -0.125961
# health__pct_physical_inacticity                                          0.061171
# health__air_pollution_particulate_matter                                -0.113426
# health__homicides_per_100k                                               0.117317
# health__motor_vehicle_crash_deaths_per_100k                              0.136475
# health__pop_per_dentist                                                  0.010419
# health__pop_per_primary_care_physician                                   0.063192
# heart_disease_mortality_per_100k                                         0.121956
#
#                                                   demo__pct_aged_65_years_and_older  \
# econ__pct_civilian_labor                                                   0.005105
# econ__pct_unemployment                                                    -0.049590
# econ__pct_uninsured_adults                                                -0.075758
# econ__pct_uninsured_children                                               0.083595
# demo__pct_female                                                           0.106818
# demo__pct_below_18_years_of_age                                           -0.566433
# demo__pct_aged_65_years_and_older                                          1.000000
# demo__pct_hispanic                                                        -0.245170
# demo__pct_non_hispanic_african_american                                   -0.225004
# demo__pct_non_hispanic_white                                               0.443333
# demo__pct_american_indian_or_alaskan_native                               -0.174043
# demo__pct_asian                                                           -0.318555
# demo__pct_adults_less_than_a_high_school_diploma                          -0.141437
# demo__pct_adults_with_high_school_diploma                                  0.303670
# demo__pct_adults_with_some_college                                         0.135045
# demo__pct_adults_bachelors_or_higher                                      -0.211250
# demo__birth_rate_per_1k                                                   -0.518523
# demo__death_rate_per_1k                                                    0.641700
# health__pct_adult_obesity                                                 -0.035280
# health__pct_adult_smoking                                                  0.038207
# health__pct_diabetes                                                       0.213014
# health__pct_low_birthweight                                               -0.076327
# health__pct_excessive_drinking                                             0.069281
# health__pct_physical_inacticity                                            0.164289
# health__air_pollution_particulate_matter                                  -0.074186
# health__homicides_per_100k                                                -0.075816
# health__motor_vehicle_crash_deaths_per_100k                                0.214857
# health__pop_per_dentist                                                    0.049268
# health__pop_per_primary_care_physician                                    -0.004279
# heart_disease_mortality_per_100k                                          -0.056203
#
#                                                   demo__pct_hispanic  \
# econ__pct_civilian_labor                                    0.006413
# econ__pct_unemployment                                     -0.023614
# econ__pct_uninsured_adults                                  0.477905
# econ__pct_uninsured_children                                0.441586
# demo__pct_female                                           -0.161775
# demo__pct_below_18_years_of_age                             0.320619
# demo__pct_aged_65_years_and_older                          -0.245170
# demo__pct_hispanic                                          1.000000
# demo__pct_non_hispanic_african_american                    -0.105977
# demo__pct_non_hispanic_white                               -0.606503
# demo__pct_american_indian_or_alaskan_native                -0.014196
# demo__pct_asian                                             0.170148
# demo__pct_adults_less_than_a_high_school_diploma            0.437311
# demo__pct_adults_with_high_school_diploma                  -0.317864
# demo__pct_adults_with_some_college                         -0.100377
# demo__pct_adults_bachelors_or_higher                       -0.023831
# demo__birth_rate_per_1k                                     0.305104
# demo__death_rate_per_1k                                    -0.297895
# health__pct_adult_obesity                                  -0.246222
# health__pct_adult_smoking                                  -0.203549
# health__pct_diabetes                                       -0.252581
# health__pct_low_birthweight                                -0.005086
# health__pct_excessive_drinking                             -0.031318
# health__pct_physical_inacticity                            -0.215272
# health__air_pollution_particulate_matter                   -0.392282
# health__homicides_per_100k                                 -0.042616
# health__motor_vehicle_crash_deaths_per_100k                -0.053457
# health__pop_per_dentist                                     0.033520
# health__pop_per_primary_care_physician                      0.000065
# heart_disease_mortality_per_100k                           -0.112437
#
#                                                   demo__pct_non_hispanic_african_american  \
# econ__pct_civilian_labor                                                        -0.344771
# econ__pct_unemployment                                                           0.382720
# econ__pct_uninsured_adults                                                       0.206069
# econ__pct_uninsured_children                                                    -0.102605
# demo__pct_female                                                                 0.098055
# demo__pct_below_18_years_of_age                                                  0.021930
# demo__pct_aged_65_years_and_older                                               -0.225004
# demo__pct_hispanic                                                              -0.105977
# demo__pct_non_hispanic_african_american                                          1.000000
# demo__pct_non_hispanic_white                                                    -0.593988
# demo__pct_american_indian_or_alaskan_native                                     -0.102537
# demo__pct_asian                                                                  0.021415
# demo__pct_adults_less_than_a_high_school_diploma                                 0.353568
# demo__pct_adults_with_high_school_diploma                                       -0.046056
# demo__pct_adults_with_some_college                                              -0.254590
# demo__pct_adults_bachelors_or_higher                                            -0.084342
# demo__birth_rate_per_1k                                                          0.066101
# demo__death_rate_per_1k                                                          0.028557
# health__pct_adult_obesity                                                        0.407675
# health__pct_adult_smoking                                                        0.025176
# health__pct_diabetes                                                             0.486529
# health__pct_low_birthweight                                                      0.681410
# health__pct_excessive_drinking                                                  -0.284243
# health__pct_physical_inacticity                                                  0.257043
# health__air_pollution_particulate_matter                                         0.166423
# health__homicides_per_100k                                                       0.694183
# health__motor_vehicle_crash_deaths_per_100k                                      0.106834
# health__pop_per_dentist                                                          0.148207
# health__pop_per_primary_care_physician                                           0.108058
# heart_disease_mortality_per_100k                                                 0.375385
#
#                                                   demo__pct_non_hispanic_white  \
# econ__pct_civilian_labor                                              0.272709
# econ__pct_unemployment                                               -0.318868
# econ__pct_uninsured_adults                                           -0.553043
# econ__pct_uninsured_children                                         -0.296403
# demo__pct_female                                                      0.066155
# demo__pct_below_18_years_of_age                                      -0.372009
# demo__pct_aged_65_years_and_older                                     0.443333
# demo__pct_hispanic                                                   -0.606503
# demo__pct_non_hispanic_african_american                              -0.593988
# demo__pct_non_hispanic_white                                          1.000000
# demo__pct_american_indian_or_alaskan_native                          -0.330840
# demo__pct_asian                                                      -0.255790
# demo__pct_adults_less_than_a_high_school_diploma                     -0.528671
# demo__pct_adults_with_high_school_diploma                             0.310179
# demo__pct_adults_with_some_college                                    0.210041
# demo__pct_adults_bachelors_or_higher                                  0.035379
# demo__birth_rate_per_1k                                              -0.411508
# demo__death_rate_per_1k                                               0.254981
# health__pct_adult_obesity                                            -0.132844
# health__pct_adult_smoking                                             0.039222
# health__pct_diabetes                                                 -0.157388
# health__pct_low_birthweight                                          -0.418430
# health__pct_excessive_drinking                                        0.164171
# health__pct_physical_inacticity                                      -0.001750
# health__air_pollution_particulate_matter                              0.227679
# health__homicides_per_100k                                           -0.578210
# health__motor_vehicle_crash_deaths_per_100k                          -0.114775
# health__pop_per_dentist                                              -0.057082
# health__pop_per_primary_care_physician                               -0.039831
# heart_disease_mortality_per_100k                                     -0.157544
#
#                                                   demo__pct_american_indian_or_alaskan_native  \
# econ__pct_civilian_labor                                                            -0.135591
# econ__pct_unemployment                                                               0.190529
# econ__pct_uninsured_adults                                                           0.244569
# econ__pct_uninsured_children                                                         0.203009
# demo__pct_female                                                                    -0.067177
# demo__pct_below_18_years_of_age                                                      0.338919
# demo__pct_aged_65_years_and_older                                                   -0.174043
# demo__pct_hispanic                                                                  -0.014196
# demo__pct_non_hispanic_african_american                                             -0.102537
# demo__pct_non_hispanic_white                                                        -0.330840
# demo__pct_american_indian_or_alaskan_native                                          1.000000
# demo__pct_asian                                                                     -0.032810
# demo__pct_adults_less_than_a_high_school_diploma                                     0.031999
# demo__pct_adults_with_high_school_diploma                                            0.008903
# demo__pct_adults_with_some_college                                                   0.093689
# demo__pct_adults_bachelors_or_higher                                                -0.086415
# demo__birth_rate_per_1k                                                              0.356814
# demo__death_rate_per_1k                                                             -0.057208
# health__pct_adult_obesity                                                            0.135914
# health__pct_adult_smoking                                                            0.206414
# health__pct_diabetes                                                                 0.066586
# health__pct_low_birthweight                                                         -0.104540
# health__pct_excessive_drinking                                                       0.085307
# health__pct_physical_inacticity                                                      0.050248
# health__air_pollution_particulate_matter                                            -0.158635
# health__homicides_per_100k                                                           0.188413
# health__motor_vehicle_crash_deaths_per_100k                                          0.355289
# health__pop_per_dentist                                                             -0.079243
# health__pop_per_primary_care_physician                                              -0.024128
# heart_disease_mortality_per_100k                                                     0.004626
#
#                                                   demo__pct_asian  \
# econ__pct_civilian_labor                                 0.177972
# econ__pct_unemployment                                  -0.088859
# econ__pct_uninsured_adults                              -0.107385
# econ__pct_uninsured_children                            -0.088984
# demo__pct_female                                         0.011124
# demo__pct_below_18_years_of_age                          0.017484
# demo__pct_aged_65_years_and_older                       -0.318555
# demo__pct_hispanic                                       0.170148
# demo__pct_non_hispanic_african_american                  0.021415
# demo__pct_non_hispanic_white                            -0.255790
# demo__pct_american_indian_or_alaskan_native             -0.032810
# demo__pct_asian                                          1.000000
# demo__pct_adults_less_than_a_high_school_diploma        -0.136437
# demo__pct_adults_with_high_school_diploma               -0.463224
# demo__pct_adults_with_some_college                      -0.075791
# demo__pct_adults_bachelors_or_higher                     0.514879
# demo__birth_rate_per_1k                                  0.076521
# demo__death_rate_per_1k                                 -0.367897
# health__pct_adult_obesity                               -0.339152
# health__pct_adult_smoking                               -0.300080
# health__pct_diabetes                                    -0.311511
# health__pct_low_birthweight                             -0.122425
# health__pct_excessive_drinking                           0.058771
# health__pct_physical_inacticity                         -0.382448
# health__air_pollution_particulate_matter                -0.113354
# health__homicides_per_100k                              -0.144628
# health__motor_vehicle_crash_deaths_per_100k             -0.371687
# health__pop_per_dentist                                 -0.217849
# health__pop_per_primary_care_physician                  -0.174783
# heart_disease_mortality_per_100k                        -0.267458
#
#                                                   demo__pct_adults_less_than_a_high_school_diploma  \
# econ__pct_civilian_labor                                                                 -0.520928
# econ__pct_unemployment                                                                    0.417660
# econ__pct_uninsured_adults                                                                0.663280
# econ__pct_uninsured_children                                                              0.281981
# demo__pct_female                                                                         -0.132861
# demo__pct_below_18_years_of_age                                                           0.220713
# demo__pct_aged_65_years_and_older                                                        -0.141437
# demo__pct_hispanic                                                                        0.437311
# demo__pct_non_hispanic_african_american                                                   0.353568
# demo__pct_non_hispanic_white                                                             -0.528671
# demo__pct_american_indian_or_alaskan_native                                               0.031999
# demo__pct_asian                                                                          -0.136437
# demo__pct_adults_less_than_a_high_school_diploma                                          1.000000
# demo__pct_adults_with_high_school_diploma                                                 0.186135
# demo__pct_adults_with_some_college                                                       -0.526815
# demo__pct_adults_bachelors_or_higher                                                     -0.602165
# demo__birth_rate_per_1k                                                                   0.223924
# demo__death_rate_per_1k                                                                   0.142624
# health__pct_adult_obesity                                                                 0.397545
# health__pct_adult_smoking                                                                 0.377551
# health__pct_diabetes                                                                      0.455894
# health__pct_low_birthweight                                                               0.456932
# health__pct_excessive_drinking                                                           -0.412436
# health__pct_physical_inacticity                                                           0.455372
# health__air_pollution_particulate_matter                                                  0.007968
# health__homicides_per_100k                                                                0.467975
# health__motor_vehicle_crash_deaths_per_100k                                               0.406717
# health__pop_per_dentist                                                                   0.394495
# health__pop_per_primary_care_physician                                                    0.290680
# heart_disease_mortality_per_100k                                                          0.527382
#
#                                                   demo__pct_adults_with_high_school_diploma  \
# econ__pct_civilian_labor                                                          -0.221864
# econ__pct_unemployment                                                             0.188042
# econ__pct_uninsured_adults                                                         0.029720
# econ__pct_uninsured_children                                                      -0.079490
# demo__pct_female                                                                  -0.105611
# demo__pct_below_18_years_of_age                                                   -0.115838
# demo__pct_aged_65_years_and_older                                                  0.303670
# demo__pct_hispanic                                                                -0.317864
# demo__pct_non_hispanic_african_american                                           -0.046056
# demo__pct_non_hispanic_white                                                       0.310179
# demo__pct_american_indian_or_alaskan_native                                        0.008903
# demo__pct_asian                                                                   -0.463224
# demo__pct_adults_less_than_a_high_school_diploma                                   0.186135
# demo__pct_adults_with_high_school_diploma                                          1.000000
# demo__pct_adults_with_some_college                                                -0.328205
# demo__pct_adults_bachelors_or_higher                                              -0.739895
# demo__birth_rate_per_1k                                                           -0.141932
# demo__death_rate_per_1k                                                            0.455295
# health__pct_adult_obesity                                                          0.485838
# health__pct_adult_smoking                                                          0.480190
# health__pct_diabetes                                                               0.447268
# health__pct_low_birthweight                                                        0.096412
# health__pct_excessive_drinking                                                    -0.048272
# health__pct_physical_inacticity                                                    0.558585
# health__air_pollution_particulate_matter                                           0.222230
# health__homicides_per_100k                                                         0.079129
# health__motor_vehicle_crash_deaths_per_100k                                        0.369555
# health__pop_per_dentist                                                            0.306245
# health__pop_per_primary_care_physician                                             0.273100
# heart_disease_mortality_per_100k                                                   0.428137
#
#                                                   demo__pct_adults_with_some_college  \
# econ__pct_civilian_labor                                                    0.239878
# econ__pct_unemployment                                                     -0.236731
# econ__pct_uninsured_adults                                                 -0.235539
# econ__pct_uninsured_children                                                0.040217
# demo__pct_female                                                            0.011703
# demo__pct_below_18_years_of_age                                             0.043561
# demo__pct_aged_65_years_and_older                                           0.135045
# demo__pct_hispanic                                                         -0.100377
# demo__pct_non_hispanic_african_american                                    -0.254590
# demo__pct_non_hispanic_white                                                0.210041
# demo__pct_american_indian_or_alaskan_native                                 0.093689
# demo__pct_asian                                                            -0.075791
# demo__pct_adults_less_than_a_high_school_diploma                           -0.526815
# demo__pct_adults_with_high_school_diploma                                  -0.328205
# demo__pct_adults_with_some_college                                          1.000000
# demo__pct_adults_bachelors_or_higher                                        0.075816
# demo__birth_rate_per_1k                                                     0.038710
# demo__death_rate_per_1k                                                    -0.042551
# health__pct_adult_obesity                                                  -0.180170
# health__pct_adult_smoking                                                  -0.220110
# health__pct_diabetes                                                       -0.301973
# health__pct_low_birthweight                                                -0.316112
# health__pct_excessive_drinking                                              0.239967
# health__pct_physical_inacticity                                            -0.288391
# health__air_pollution_particulate_matter                                   -0.190326
# health__homicides_per_100k                                                 -0.162075
# health__motor_vehicle_crash_deaths_per_100k                                -0.095026
# health__pop_per_dentist                                                    -0.218062
# health__pop_per_primary_care_physician                                     -0.112448
# heart_disease_mortality_per_100k                                           -0.340764
#
#                                                   demo__pct_adults_bachelors_or_higher  \
# econ__pct_civilian_labor                                                      0.432600
# econ__pct_unemployment                                                       -0.328854
# econ__pct_uninsured_adults                                                   -0.391967
# econ__pct_uninsured_children                                                 -0.176100
# demo__pct_female                                                              0.178108
# demo__pct_below_18_years_of_age                                              -0.102530
# demo__pct_aged_65_years_and_older                                            -0.211250
# demo__pct_hispanic                                                           -0.023831
# demo__pct_non_hispanic_african_american                                      -0.084342
# demo__pct_non_hispanic_white                                                  0.035379
# demo__pct_american_indian_or_alaskan_native                                  -0.086415
# demo__pct_asian                                                               0.514879
# demo__pct_adults_less_than_a_high_school_diploma                             -0.602165
# demo__pct_adults_with_high_school_diploma                                    -0.739895
# demo__pct_adults_with_some_college                                            0.075816
# demo__pct_adults_bachelors_or_higher                                          1.000000
# demo__birth_rate_per_1k                                                      -0.081568
# demo__death_rate_per_1k                                                      -0.443685
# health__pct_adult_obesity                                                    -0.582092
# health__pct_adult_smoking                                                    -0.522427
# health__pct_diabetes                                                         -0.524740
# health__pct_low_birthweight                                                  -0.240317
# health__pct_excessive_drinking                                                0.172441
# health__pct_physical_inacticity                                              -0.620314
# health__air_pollution_particulate_matter                                     -0.070287
# health__homicides_per_100k                                                   -0.273658
# health__motor_vehicle_crash_deaths_per_100k                                  -0.536784
# health__pop_per_dentist                                                      -0.406464
# health__pop_per_primary_care_physician                                       -0.366908
# heart_disease_mortality_per_100k                                             -0.541385
#
#                                                   demo__birth_rate_per_1k  \
# econ__pct_civilian_labor                                        -0.004480
# econ__pct_unemployment                                          -0.012124
# econ__pct_uninsured_adults                                       0.283840
# econ__pct_uninsured_children                                     0.161277
# demo__pct_female                                                 0.105928
# demo__pct_below_18_years_of_age                                  0.729499
# demo__pct_aged_65_years_and_older                               -0.518523
# demo__pct_hispanic                                               0.305104
# demo__pct_non_hispanic_african_american                          0.066101
# demo__pct_non_hispanic_white                                    -0.411508
# demo__pct_american_indian_or_alaskan_native                      0.356814
# demo__pct_asian                                                  0.076521
# demo__pct_adults_less_than_a_high_school_diploma                 0.223924
# demo__pct_adults_with_high_school_diploma                       -0.141932
# demo__pct_adults_with_some_college                               0.038710
# demo__pct_adults_bachelors_or_higher                            -0.081568
# demo__birth_rate_per_1k                                          1.000000
# demo__death_rate_per_1k                                         -0.232399
# health__pct_adult_obesity                                        0.174460
# health__pct_adult_smoking                                        0.038505
# health__pct_diabetes                                            -0.046936
# health__pct_low_birthweight                                     -0.005373
# health__pct_excessive_drinking                                  -0.108256
# health__pct_physical_inacticity                                  0.090595
# health__air_pollution_particulate_matter                        -0.150237
# health__homicides_per_100k                                       0.251163
# health__motor_vehicle_crash_deaths_per_100k                      0.122453
# health__pop_per_dentist                                         -0.070077
# health__pop_per_primary_care_physician                          -0.018789
# heart_disease_mortality_per_100k                                 0.142176
#
#                                                   demo__death_rate_per_1k  \
# econ__pct_civilian_labor                                        -0.280318
# econ__pct_unemployment                                           0.190105
# econ__pct_uninsured_adults                                       0.060668
# econ__pct_uninsured_children                                    -0.049375
# demo__pct_female                                                 0.183712
# demo__pct_below_18_years_of_age                                 -0.300698
# demo__pct_aged_65_years_and_older                                0.641700
# demo__pct_hispanic                                              -0.297895
# demo__pct_non_hispanic_african_american                          0.028557
# demo__pct_non_hispanic_white                                     0.254981
# demo__pct_american_indian_or_alaskan_native                     -0.057208
# demo__pct_asian                                                 -0.367897
# demo__pct_adults_less_than_a_high_school_diploma                 0.142624
# demo__pct_adults_with_high_school_diploma                        0.455295
# demo__pct_adults_with_some_college                              -0.042551
# demo__pct_adults_bachelors_or_higher                            -0.443685
# demo__birth_rate_per_1k                                         -0.232399
# demo__death_rate_per_1k                                          1.000000
# health__pct_adult_obesity                                        0.320024
# health__pct_adult_smoking                                        0.347203
# health__pct_diabetes                                             0.484927
# health__pct_low_birthweight                                      0.188212
# health__pct_excessive_drinking                                  -0.149701
# health__pct_physical_inacticity                                  0.479897
# health__air_pollution_particulate_matter                         0.062434
# health__homicides_per_100k                                       0.233410
# health__motor_vehicle_crash_deaths_per_100k                      0.377897
# health__pop_per_dentist                                          0.153025
# health__pop_per_primary_care_physician                           0.059936
# heart_disease_mortality_per_100k                                 0.444757
#
#                                                   health__pct_adult_obesity  \
# econ__pct_civilian_labor                                          -0.370449
# econ__pct_unemployment                                             0.292533
# econ__pct_uninsured_adults                                         0.180362
# econ__pct_uninsured_children                                      -0.128264
# demo__pct_female                                                   0.042139
# demo__pct_below_18_years_of_age                                    0.170959
# demo__pct_aged_65_years_and_older                                 -0.035280
# demo__pct_hispanic                                                -0.246222
# demo__pct_non_hispanic_african_american                            0.407675
# demo__pct_non_hispanic_white                                      -0.132844
# demo__pct_american_indian_or_alaskan_native                        0.135914
# demo__pct_asian                                                   -0.339152
# demo__pct_adults_less_than_a_high_school_diploma                   0.397545
# demo__pct_adults_with_high_school_diploma                          0.485838
# demo__pct_adults_with_some_college                                -0.180170
# demo__pct_adults_bachelors_or_higher                              -0.582092
# demo__birth_rate_per_1k                                            0.174460
# ...
# econ__pct_uninsured_adults                                                       -0.219350
# econ__pct_uninsured_children                                                     -0.345746
# demo__pct_female                                                                  0.109214
# demo__pct_below_18_years_of_age                                                  -0.113426
# demo__pct_aged_65_years_and_older                                                -0.074186
# demo__pct_hispanic                                                               -0.392282
# demo__pct_non_hispanic_african_american                                           0.166423
# demo__pct_non_hispanic_white                                                      0.227679
# demo__pct_american_indian_or_alaskan_native                                      -0.158635
# demo__pct_asian                                                                  -0.113354
# demo__pct_adults_less_than_a_high_school_diploma                                  0.007968
# demo__pct_adults_with_high_school_diploma                                         0.222230
# demo__pct_adults_with_some_college                                               -0.190326
# demo__pct_adults_bachelors_or_higher                                             -0.070287
# demo__birth_rate_per_1k                                                          -0.150237
# demo__death_rate_per_1k                                                           0.062434
# health__pct_adult_obesity                                                         0.136686
# health__pct_adult_smoking                                                         0.202393
# health__pct_diabetes                                                              0.195801
# health__pct_low_birthweight                                                       0.212074
# health__pct_excessive_drinking                                                   -0.195330
# health__pct_physical_inacticity                                                   0.182510
# health__air_pollution_particulate_matter                                          1.000000
# health__homicides_per_100k                                                        0.015425
# health__motor_vehicle_crash_deaths_per_100k                                      -0.063499
# health__pop_per_dentist                                                           0.064812
# health__pop_per_primary_care_physician                                            0.036263
# heart_disease_mortality_per_100k                                                  0.150019
#
#                                                   health__homicides_per_100k  \
# econ__pct_civilian_labor                                           -0.391567
# econ__pct_unemployment                                              0.418517
# econ__pct_uninsured_adults                                          0.410288
# econ__pct_uninsured_children                                        0.109011
# demo__pct_female                                                    0.150494
# demo__pct_below_18_years_of_age                                     0.117317
# demo__pct_aged_65_years_and_older                                  -0.075816
# demo__pct_hispanic                                                 -0.042616
# demo__pct_non_hispanic_african_american                             0.694183
# demo__pct_non_hispanic_white                                       -0.578210
# demo__pct_american_indian_or_alaskan_native                         0.188413
# demo__pct_asian                                                    -0.144628
# demo__pct_adults_less_than_a_high_school_diploma                    0.467975
# demo__pct_adults_with_high_school_diploma                           0.079129
# demo__pct_adults_with_some_college                                 -0.162075
# demo__pct_adults_bachelors_or_higher                               -0.273658
# demo__birth_rate_per_1k                                             0.251163
# demo__death_rate_per_1k                                             0.233410
# health__pct_adult_obesity                                           0.461949
# health__pct_adult_smoking                                           0.203148
# health__pct_diabetes                                                0.470280
# health__pct_low_birthweight                                         0.635791
# health__pct_excessive_drinking                                     -0.199509
# health__pct_physical_inacticity                                     0.383272
# health__air_pollution_particulate_matter                            0.015425
# health__homicides_per_100k                                          1.000000
# health__motor_vehicle_crash_deaths_per_100k                         0.402584
# health__pop_per_dentist                                             0.170556
# health__pop_per_primary_care_physician                              0.129652
# heart_disease_mortality_per_100k                                    0.441164
#
#                                                   health__motor_vehicle_crash_deaths_per_100k  \
# econ__pct_civilian_labor                                                            -0.346759
# econ__pct_unemployment                                                               0.229797
# econ__pct_uninsured_adults                                                           0.455132
# econ__pct_uninsured_children                                                         0.406176
# demo__pct_female                                                                    -0.078898
# demo__pct_below_18_years_of_age                                                      0.136475
# demo__pct_aged_65_years_and_older                                                    0.214857
# demo__pct_hispanic                                                                  -0.053457
# demo__pct_non_hispanic_african_american                                              0.106834
# demo__pct_non_hispanic_white                                                        -0.114775
# demo__pct_american_indian_or_alaskan_native                                          0.355289
# demo__pct_asian                                                                     -0.371687
# demo__pct_adults_less_than_a_high_school_diploma                                     0.406717
# demo__pct_adults_with_high_school_diploma                                            0.369555
# demo__pct_adults_with_some_college                                                  -0.095026
# demo__pct_adults_bachelors_or_higher                                                -0.536784
# demo__birth_rate_per_1k                                                              0.122453
# demo__death_rate_per_1k                                                              0.377897
# health__pct_adult_obesity                                                            0.395990
# health__pct_adult_smoking                                                            0.349670
# health__pct_diabetes                                                                 0.439391
# health__pct_low_birthweight                                                          0.266386
# health__pct_excessive_drinking                                                      -0.175239
# health__pct_physical_inacticity                                                      0.511724
# health__air_pollution_particulate_matter                                            -0.063499
# health__homicides_per_100k                                                           0.402584
# health__motor_vehicle_crash_deaths_per_100k                                          1.000000
# health__pop_per_dentist                                                              0.319354
# health__pop_per_primary_care_physician                                               0.298046
# heart_disease_mortality_per_100k                                                     0.459803
#
#                                                   health__pop_per_dentist  \
# econ__pct_civilian_labor                                        -0.285938
# econ__pct_unemployment                                           0.178324
# econ__pct_uninsured_adults                                       0.237915
# econ__pct_uninsured_children                                     0.152708
# demo__pct_female                                                -0.131156
# demo__pct_below_18_years_of_age                                  0.010419
# demo__pct_aged_65_years_and_older                                0.049268
# demo__pct_hispanic                                               0.033520
# demo__pct_non_hispanic_african_american                          0.148207
# demo__pct_non_hispanic_white                                    -0.057082
# demo__pct_american_indian_or_alaskan_native                     -0.079243
# demo__pct_asian                                                 -0.217849
# demo__pct_adults_less_than_a_high_school_diploma                 0.394495
# demo__pct_adults_with_high_school_diploma                        0.306245
# demo__pct_adults_with_some_college                              -0.218062
# demo__pct_adults_bachelors_or_higher                            -0.406464
# demo__birth_rate_per_1k                                         -0.070077
# demo__death_rate_per_1k                                          0.153025
# health__pct_adult_obesity                                        0.251980
# health__pct_adult_smoking                                        0.299328
# health__pct_diabetes                                             0.264966
# health__pct_low_birthweight                                      0.213836
# health__pct_excessive_drinking                                  -0.124950
# health__pct_physical_inacticity                                  0.319298
# health__air_pollution_particulate_matter                         0.064812
# health__homicides_per_100k                                       0.170556
# health__motor_vehicle_crash_deaths_per_100k                      0.319354
# health__pop_per_dentist                                          1.000000
# health__pop_per_primary_care_physician                           0.462281
# heart_disease_mortality_per_100k                                 0.301232
#
#                                                   health__pop_per_primary_care_physician  \
# econ__pct_civilian_labor                                                       -0.218591
# econ__pct_unemployment                                                          0.136225
# econ__pct_uninsured_adults                                                      0.165261
# econ__pct_uninsured_children                                                    0.103520
# demo__pct_female                                                               -0.131682
# demo__pct_below_18_years_of_age                                                 0.063192
# demo__pct_aged_65_years_and_older                                              -0.004279
# demo__pct_hispanic                                                              0.000065
# demo__pct_non_hispanic_african_american                                         0.108058
# demo__pct_non_hispanic_white                                                   -0.039831
# demo__pct_american_indian_or_alaskan_native                                    -0.024128
# demo__pct_asian                                                                -0.174783
# demo__pct_adults_less_than_a_high_school_diploma                                0.290680
# demo__pct_adults_with_high_school_diploma                                       0.273100
# demo__pct_adults_with_some_college                                             -0.112448
# demo__pct_adults_bachelors_or_higher                                           -0.366908
# demo__birth_rate_per_1k                                                        -0.018789
# demo__death_rate_per_1k                                                         0.059936
# health__pct_adult_obesity                                                       0.231476
# health__pct_adult_smoking                                                       0.243189
# health__pct_diabetes                                                            0.219240
# health__pct_low_birthweight                                                     0.112327
# health__pct_excessive_drinking                                                 -0.045953
# health__pct_physical_inacticity                                                 0.251822
# health__air_pollution_particulate_matter                                        0.036263
# health__homicides_per_100k                                                      0.129652
# health__motor_vehicle_crash_deaths_per_100k                                     0.298046
# health__pop_per_dentist                                                         0.462281
# health__pop_per_primary_care_physician                                          1.000000
# heart_disease_mortality_per_100k                                                0.219111
#
#                                                   heart_disease_mortality_per_100k
# econ__pct_civilian_labor                                                 -0.476644
# econ__pct_unemployment                                                    0.371620
# econ__pct_uninsured_adults                                                0.334217
# econ__pct_uninsured_children                                             -0.034482
# demo__pct_female                                                          0.087040
# demo__pct_below_18_years_of_age                                           0.121956
# demo__pct_aged_65_years_and_older                                        -0.056203
# demo__pct_hispanic                                                       -0.112437
# demo__pct_non_hispanic_african_american                                   0.375385
# demo__pct_non_hispanic_white                                             -0.157544
# demo__pct_american_indian_or_alaskan_native                               0.004626
# demo__pct_asian                                                          -0.267458
# demo__pct_adults_less_than_a_high_school_diploma                          0.527382
# demo__pct_adults_with_high_school_diploma                                 0.428137
# demo__pct_adults_with_some_college                                       -0.340764
# demo__pct_adults_bachelors_or_higher                                     -0.541385
# demo__birth_rate_per_1k                                                   0.142176
# demo__death_rate_per_1k                                                   0.444757
# health__pct_adult_obesity                                                 0.593775
# health__pct_adult_smoking                                                 0.497063
# health__pct_diabetes                                                      0.631765
# health__pct_low_birthweight                                               0.476757
# health__pct_excessive_drinking                                           -0.382172
# health__pct_physical_inacticity                                           0.650305
# health__air_pollution_particulate_matter                                  0.150019
# health__homicides_per_100k                                                0.441164
# health__motor_vehicle_crash_deaths_per_100k                               0.459803
# health__pop_per_dentist                                                   0.301232
# health__pop_per_primary_care_physician                                    0.219111
# heart_disease_mortality_per_100k                                          1.000000

# %%
df.head()
# Out:
#                                           area__rucc  \
# 0  Metro - Counties in metro areas of fewer than ...
# 1  Metro - Counties in metro areas of fewer than ...
# 2  Metro - Counties in metro areas of 1 million p...
# 3  Nonmetro - Urban population of 2,500 to 19,999...
# 4  Nonmetro - Urban population of 2,500 to 19,999...
#
#                                area__urban_influence  econ__economic_typology  \
# 0  Small-in a metro area with fewer than 1 millio...  Manufacturing-dependent
# 1  Small-in a metro area with fewer than 1 millio...         Mining-dependent
# 2  Large-in a metro area with at least 1 million ...           Nonspecialized
# 3  Noncore adjacent to a small metro with town of...           Nonspecialized
# 4  Noncore not adjacent to a metro/micro area and...           Nonspecialized
#
#    econ__pct_civilian_labor  econ__pct_unemployment  \
# 0                     0.408                   0.057
# 1                     0.556                   0.039
# 2                     0.541                   0.057
# 3                     0.500                   0.061
# 4                     0.471                   0.050
#
#    econ__pct_uninsured_adults  econ__pct_uninsured_children  demo__pct_female  \
# 0                       0.254                         0.066             0.516
# 1                       0.260                         0.143             0.503
# 2                       0.070                         0.023             0.522
# 3                       0.203                         0.059             0.525
# 4                       0.225                         0.103             0.511
#
#    demo__pct_below_18_years_of_age  demo__pct_aged_65_years_and_older  \
# 0                            0.235                              0.176
# 1                            0.272                              0.101
# 2                            0.179                              0.115
# 3                            0.200                              0.164
# 4                            0.237                              0.171
#
#    demo__pct_hispanic  demo__pct_non_hispanic_african_american  \
# 0               0.109                                    0.039
# 1               0.410                                    0.070
# 2               0.202                                    0.198
# 3               0.013                                    0.049
# 4               0.025                                    0.008
#
#    demo__pct_non_hispanic_white  demo__pct_american_indian_or_alaskan_native  \
# 0                         0.829                                        0.004
# 1                         0.493                                        0.008
# 2                         0.479                                        0.013
# 3                         0.897                                        0.007
# 4                         0.953                                        0.003
#
#    demo__pct_asian  demo__pct_adults_less_than_a_high_school_diploma  \
# 0            0.011                                          0.194223
# 1            0.015                                          0.164134
# 2            0.085                                          0.158573
# 3            0.001                                          0.181637
# 4            0.000                                          0.122367
#
#    demo__pct_adults_with_high_school_diploma  \
# 0                                   0.424303
# 1                                   0.234043
# 2                                   0.237859
# 3                                   0.407186
# 4                                   0.413240
#
#    demo__pct_adults_with_some_college  demo__pct_adults_bachelors_or_higher  \
# 0                            0.227092                              0.154382
# 1                            0.342452                              0.259372
# 2                            0.186323                              0.417245
# 3                            0.248503                              0.162675
# 4                            0.306921                              0.157472
#
#    demo__birth_rate_per_1k  demo__death_rate_per_1k  \
# 0                       12                       12
# 1                       19                        7
# 2                       12                        6
# 3                       11                       12
# 4                       14                       12
#
#    health__pct_adult_obesity  health__pct_adult_smoking  health__pct_diabetes  \
# 0                      0.297                      0.230                 0.131
# 1                      0.288                      0.190                 0.090
# 2                      0.212                      0.156                 0.084
# 3                      0.285                        NaN                 0.104
# 4                      0.284                      0.234                 0.137
#
#    health__pct_low_birthweight  health__pct_excessive_drinking  \
# 0                        0.089                             NaN
# 1                        0.082                           0.181
# 2                        0.098                           0.195
# 3                        0.058                             NaN
# 4                        0.070                           0.194
#
#    health__pct_physical_inacticity  health__air_pollution_particulate_matter  \
# 0                            0.332                                      13.0
# 1                            0.265                                      10.0
# 2                            0.209                                      10.0
# 3                            0.238                                      13.0
# 4                            0.290                                       9.0
#
#    health__homicides_per_100k  health__motor_vehicle_crash_deaths_per_100k  \
# 0                        2.80                                        15.09
# 1                        2.30                                        19.79
# 2                        9.31                                         3.14
# 3                         NaN                                          NaN
# 4                         NaN                                        29.39
#
#    health__pop_per_dentist  health__pop_per_primary_care_physician yr  \
# 0                   1650.0                                  1489.0  a
# 1                   2010.0                                  2480.0  a
# 2                    629.0                                   690.0  b
# 3                   1810.0                                  6630.0  b
# 4                   3489.0                                  2590.0  a
#
#    heart_disease_mortality_per_100k
# 0                               312
# 1                               257
# 2                               195
# 3                               218
# 4                               355

# %%
#sns.barplot(df['area__rucc'],df['heart_disease_mortality_per_100k'])

# %% [markdown]
# Handling NaN values

# %%
df['econ__pct_uninsured_adults'].fillna(df['econ__pct_uninsured_adults'].mean(),inplace=True)
df['econ__pct_uninsured_children'].fillna(df['econ__pct_uninsured_children'].mean(),inplace=True)

df['demo__pct_female'].fillna(df['demo__pct_female'].mean(),inplace=True)
df['demo__pct_below_18_years_of_age'].fillna(df['demo__pct_below_18_years_of_age'].mean(),inplace=True)

df['demo__pct_aged_65_years_and_older'].fillna(df['demo__pct_aged_65_years_and_older'].mean(),inplace=True)
df['demo__pct_hispanic'].fillna(0.019,inplace=True)

df['demo__pct_non_hispanic_african_american'].fillna(0.0,inplace=True)
df['demo__pct_non_hispanic_white'].fillna(df['demo__pct_non_hispanic_white'].mean(),inplace=True)

df['demo__pct_american_indian_or_alaskan_native'].fillna(0.0,inplace=True)
df['demo__pct_asian'].fillna(0.0,inplace=True)

df['health__pct_adult_obesity'].fillna(df['health__pct_adult_obesity'].mean(),inplace=True)
df['health__pct_adult_smoking'].fillna(df['health__pct_adult_smoking'].mean(),inplace=True)
df['health__pct_physical_inacticity'].fillna(df['health__pct_physical_inacticity'].mean(),inplace=True)
df['health__homicides_per_100k'].fillna(df['health__homicides_per_100k'].median(),inplace=True)

df['health__pct_diabetes'].fillna(df['health__pct_diabetes'].median(),inplace=True)
df['health__pct_low_birthweight'].fillna(df['health__pct_low_birthweight'].mean(),inplace=True)

df['health__pct_excessive_drinking'].fillna(df['health__pct_excessive_drinking'].mean(),inplace=True)
df['health__air_pollution_particulate_matter'].fillna(11.0,inplace=True)

df['health__motor_vehicle_crash_deaths_per_100k'].fillna(df['health__motor_vehicle_crash_deaths_per_100k'].mean(),inplace=True)
df['health__pop_per_dentist'].fillna(random.uniform(3000,4000),inplace=True)
df['health__pop_per_primary_care_physician'].fillna(random.uniform(1000,2000),inplace=True)

# %%
df_ = df[df['econ__pct_uninsured_adults'].isnull()==False]
sns.distplot(df_['econ__pct_uninsured_adults'])
print("Mean:- {} , Median:- {}".format(df['econ__pct_uninsured_adults'].mean(),df['econ__pct_uninsured_adults'].median()))
# Out:
# C:\Users\Vishwarath Patil\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Mean:- 0.21746307884856103 , Median:- 0.21600000000000003

# %%
df_ = df[df['econ__pct_uninsured_children'].isnull()==False]
sns.distplot(df_['econ__pct_uninsured_children'])
print("Mean:- {} , Median:- {}".format(df['econ__pct_uninsured_children'].mean(),df['econ__pct_uninsured_children'].median()))
# Out:
# Mean:- 0.08606727158948684 , Median:- 0.077

# %%
df_ = df[df['demo__pct_female'].isnull()==False]
sns.distplot(df_['demo__pct_female'])
print("Mean:- {} , Median:- {}".format(df['demo__pct_female'].mean(),df['demo__pct_female'].median()))
# Out:
# Mean:- 0.4988107008760949 , Median:- 0.503

# %%
df_ = df[df['demo__pct_below_18_years_of_age'].isnull()==False]
sns.distplot(df_['demo__pct_below_18_years_of_age'])
print("Mean:- {} , Median:- {}".format(df['demo__pct_below_18_years_of_age'].mean(),df['demo__pct_below_18_years_of_age'].median()))
# Out:
# Mean:- 0.227714956195244 , Median:- 0.226

# %%
null_ls = ['demo__pct_aged_65_years_and_older','demo__pct_hispanic','demo__pct_non_hispanic_african_american','demo__pct_non_hispanic_white','demo__pct_american_indian_or_alaskan_native','demo__pct_asian']
for i in null_ls:
    df_ = df[df[i].isnull()==False]
    sns.distplot(df_[i])

# %%
df_ = df[df['demo__pct_aged_65_years_and_older'].isnull()==False]
sns.distplot(df_['demo__pct_aged_65_years_and_older'])
print("Mean:- {} , Median:- {}".format(df['demo__pct_aged_65_years_and_older'].mean(),df['demo__pct_aged_65_years_and_older'].median()))
# Out:
# Mean:- 0.17004317897371707 , Median:- 0.16699999999999998

# %%
df_ = df[df['demo__pct_hispanic'].isnull()==False]
sns.distplot(df_['demo__pct_hispanic'])
print("Mean:- {} , Median:- {}".format(df['demo__pct_hispanic'].mean(),df['demo__pct_hispanic'].median()))
# Out:
# Mean:- 0.09016228893058124 , Median:- 0.035

# %%
df_ = df[df['demo__pct_non_hispanic_african_american'].isnull()==False]
sns.distplot(df_['demo__pct_non_hispanic_african_american'])
print("Mean:- {} , Median:- {}".format(df['demo__pct_non_hispanic_african_american'].mean(),df['demo__pct_non_hispanic_african_american'].median()))
# Out:
# Mean:- 0.09098936835522162 , Median:- 0.022000000000000002

# %%
df_ = df[df['demo__pct_non_hispanic_white'].isnull()==False]
sns.distplot(df_['demo__pct_non_hispanic_white'],fit=norm)

# %%
df_ = df[df['demo__pct_american_indian_or_alaskan_native'].isnull()==False]
sns.distplot(df_['demo__pct_american_indian_or_alaskan_native'],fit=norm)

# %%
df_ = df[df['demo__pct_asian'].isnull()==False]
sns.distplot(df_['demo__pct_asian'],fit=norm)

# %%
df_ = df[df['health__pct_adult_obesity'].isnull()==False]
sns.distplot(df_['health__pct_adult_obesity'],fit=norm)

# %%
corrmat = df.corr()
top_corr_features = corrmat.index[abs(corrmat["health__pct_adult_smoking"]) > 0.5]
plt.figure(figsize=(10, 10))
g = sns.heatmap(df[top_corr_features].corr(), annot=True, cmap="RdYlGn")

# %%
df_= df[df['health__pct_adult_smoking'].isnull()==False]
sns.distplot(df_['health__pct_adult_smoking'],fit=norm)
print("Mean:- {} , Median:- {}".format(df_['health__pct_adult_smoking'].mean(),df_['health__pct_adult_smoking'].median()))
# Out:
# Mean:- 0.21362765179224402 , Median:- 0.2136276517922455

# %%
df_ = df[df['health__pct_adult_smoking'].isnull()==False]
plt.scatter(df_['health__pct_adult_smoking'],df_['heart_disease_mortality_per_100k'])

# %%
df_.head()
# Manual analysis how values are varies with other feature value
# Out:
#                                           area__rucc  \
# 0  Metro - Counties in metro areas of fewer than ...
# 1  Metro - Counties in metro areas of fewer than ...
# 2  Metro - Counties in metro areas of 1 million p...
# 3  Nonmetro - Urban population of 2,500 to 19,999...
# 4  Nonmetro - Urban population of 2,500 to 19,999...
#
#                                area__urban_influence  econ__economic_typology  \
# 0  Small-in a metro area with fewer than 1 millio...  Manufacturing-dependent
# 1  Small-in a metro area with fewer than 1 millio...         Mining-dependent
# 2  Large-in a metro area with at least 1 million ...           Nonspecialized
# 3  Noncore adjacent to a small metro with town of...           Nonspecialized
# 4  Noncore not adjacent to a metro/micro area and...           Nonspecialized
#
#    econ__pct_civilian_labor  econ__pct_unemployment  \
# 0                     0.408                   0.057
# 1                     0.556                   0.039
# 2                     0.541                   0.057
# 3                     0.500                   0.061
# 4                     0.471                   0.050
#
#    econ__pct_uninsured_adults  econ__pct_uninsured_children  demo__pct_female  \
# 0                       0.254                         0.066             0.516
# 1                       0.260                         0.143             0.503
# 2                       0.070                         0.023             0.522
# 3                       0.203                         0.059             0.525
# 4                       0.225                         0.103             0.511
#
#    demo__pct_below_18_years_of_age  demo__pct_aged_65_years_and_older  \
# 0                            0.235                              0.176
# 1                            0.272                              0.101
# 2                            0.179                              0.115
# 3                            0.200                              0.164
# 4                            0.237                              0.171
#
#    demo__pct_hispanic  demo__pct_non_hispanic_african_american  \
# 0               0.109                                    0.039
# 1               0.410                                    0.070
# 2               0.202                                    0.198
# 3               0.013                                    0.049
# 4               0.025                                    0.008
#
#    demo__pct_non_hispanic_white  demo__pct_american_indian_or_alaskan_native  \
# 0                         0.829                                        0.004
# 1                         0.493                                        0.008
# 2                         0.479                                        0.013
# 3                         0.897                                        0.007
# 4                         0.953                                        0.003
#
#    demo__pct_asian  demo__pct_adults_less_than_a_high_school_diploma  \
# 0            0.011                                          0.194223
# 1            0.015                                          0.164134
# 2            0.085                                          0.158573
# 3            0.001                                          0.181637
# 4            0.000                                          0.122367
#
#    demo__pct_adults_with_high_school_diploma  \
# 0                                   0.424303
# 1                                   0.234043
# 2                                   0.237859
# 3                                   0.407186
# 4                                   0.413240
#
#    demo__pct_adults_with_some_college  demo__pct_adults_bachelors_or_higher  \
# 0                            0.227092                              0.154382
# 1                            0.342452                              0.259372
# 2                            0.186323                              0.417245
# 3                            0.248503                              0.162675
# 4                            0.306921                              0.157472
#
#    demo__birth_rate_per_1k  demo__death_rate_per_1k  \
# 0                       12                       12
# 1                       19                        7
# 2                       12                        6
# 3                       11                       12
# 4                       14                       12
#
#    health__pct_adult_obesity  health__pct_adult_smoking  health__pct_diabetes  \
# 0                      0.297                   0.230000                 0.131
# 1                      0.288                   0.190000                 0.090
# 2                      0.212                   0.156000                 0.084
# 3                      0.285                   0.213628                 0.104
# 4                      0.284                   0.234000                 0.137
#
#    health__pct_low_birthweight  health__pct_excessive_drinking  \
# 0                        0.089                        0.164841
# 1                        0.082                        0.181000
# 2                        0.098                        0.195000
# 3                        0.058                        0.164841
# 4                        0.070                        0.194000
#
#    health__pct_physical_inacticity  health__air_pollution_particulate_matter  \
# 0                            0.332                                      13.0
# 1                            0.265                                      10.0
# 2                            0.209                                      10.0
# 3                            0.238                                      13.0
# 4                            0.290                                       9.0
#
#    health__homicides_per_100k  health__motor_vehicle_crash_deaths_per_100k  \
# 0                        2.80                                    15.090000
# 1                        2.30                                    19.790000
# 2                        9.31                                     3.140000
# 3                        4.70                                    21.132618
# 4                        4.70                                    29.390000
#
#    health__pop_per_dentist  health__pop_per_primary_care_physician yr  \
# 0                   1650.0                                  1489.0  a
# 1                   2010.0                                  2480.0  a
# 2                    629.0                                   690.0  b
# 3                   1810.0                                  6630.0  b
# 4                   3489.0                                  2590.0  a
#
#    heart_disease_mortality_per_100k
# 0                               312
# 1                               257
# 2                               195
# 3                               218
# 4                               355

# %%
sns.distplot(df_['health__pct_diabetes'],fit=norm)
print("Mean:- {} , Median:- {}".format(df['health__pct_diabetes'].mean(),df['health__pct_diabetes'].median()))
# Out:
# Mean:- 0.10925984990619167 , Median:- 0.109

# %%
sns.distplot(df['health__pct_low_birthweight'],fit=norm)
print("Mean:- {} , Median:- {}".format(df['health__pct_low_birthweight'].mean(),df['health__pct_low_birthweight'].median()))
# Out:
# Mean:- 0.0838958885941644 , Median:- 0.08199999999999999

# %%
corrmat = df.corr()
top_corr_features = corrmat.index[abs(corrmat["health__homicides_per_100k"]) > 0.5]
plt.figure(figsize=(10, 10))
g = sns.heatmap(df[top_corr_features].corr(), annot=True, cmap="RdYlGn")

# %%
df_= df[df['health__homicides_per_100k'].isnull()==False]
sns.distplot(df_['health__homicides_per_100k'],fit=norm)
print("Mean:- {} , Median:- {}".format(df_['health__homicides_per_100k'].mean(),df_['health__homicides_per_100k'].median()))
# Out:
# Mean:- 5.1801969981240195 , Median:- 4.7

# %%
df__ = df_[['health__pct_low_birthweight','health__homicides_per_100k','demo__pct_non_hispanic_african_american']]
df__.head(n=10)
# Out:
#    health__pct_low_birthweight  health__homicides_per_100k  \
# 0                        0.089                        2.80
# 1                        0.082                        2.30
# 2                        0.098                        9.31
# 3                        0.058                        4.70
# 4                        0.070                        4.70
# 5                        0.089                        3.80
# 6                        0.070                        4.70
# 7                        0.092                        5.60
# 8                        0.139                       13.60
# 9                        0.073                        4.70
#
#    demo__pct_non_hispanic_african_american
# 0                                    0.039
# 1                                    0.070
# 2                                    0.198
# 3                                    0.049
# 4                                    0.008
# 5                                    0.046
# 6                                    0.002
# 7                                    0.224
# 8                                    0.719
# 9                                    0.000

# %%
df_ = df[df['health__pct_excessive_drinking'].isnull()==False]
sns.distplot(df_['health__pct_excessive_drinking'],fit=norm)
print("Mean:- {} , Median:- {}".format(df_['health__pct_excessive_drinking'].mean(),df_['health__pct_excessive_drinking'].median()))
# Out:
# Mean:- 0.1648414414414451 , Median:- 0.16484144144144144

# %%
df_ = df[df['health__air_pollution_particulate_matter'].isnull()==False]
sns.distplot(df_['health__air_pollution_particulate_matter'])
df_['health__air_pollution_particulate_matter'].median()
# Out:
# 12.0

# %%
plt.figure(figsize=(12,5))
sns.countplot(df_['health__air_pollution_particulate_matter'])

# %%
corrmat = df.corr()
top_corr_features = corrmat.index[abs(corrmat["health__motor_vehicle_crash_deaths_per_100k"]) > 0.5]
plt.figure(figsize=(10, 10))
g = sns.heatmap(df[top_corr_features].corr(), annot=True, cmap="RdYlGn")

# %%
df_ = df[df['health__motor_vehicle_crash_deaths_per_100k'].isnull()==False]
sns.distplot(df_['health__motor_vehicle_crash_deaths_per_100k'],fit=norm)
print("Mean:- {} , Median:- {}".format(df_['health__air_pollution_particulate_matter'].mean(),df_['health__air_pollution_particulate_matter'].median()))
# Out:
# Mean:- 11.620387742338961 , Median:- 12.0

# %%
df_ = df[df['health__pop_per_dentist'].isnull()==False]
sns.distplot(df_['health__pop_per_dentist'],fit=norm)
print("Mean:- {} , Median:- {}".format(df_['health__pop_per_dentist'].mean(),df_['health__pop_per_dentist'].median()))
# Out:
# Mean:- 3446.8205283602047 , Median:- 2859.5

# %%
sns.boxplot(df['health__pop_per_dentist'])

# %%
df_ = df[df['health__pop_per_primary_care_physician'].isnull()==False]
sns.distplot(df_['health__pop_per_primary_care_physician'],fit=norm)
print("Mean:- {} , Median:- {}".format(df_['health__pop_per_primary_care_physician'].mean(),df_['health__pop_per_primary_care_physician'].median()))
# Out:
# Mean:- 2506.5460141458707 , Median:- 1928.5180575586255

# %%
stats.probplot(df_['health__pop_per_primary_care_physician'],plot=plt)
# Out:
# ((array([-3.51883821, -3.27621079, -3.14209787, ...,  3.14209787,
#           3.27621079,  3.51883821]),
#   array([  189.,   210.,   219., ..., 20909., 20910., 23399.])),
#  (1628.8251211247248, 2506.5460141458675, 0.8017505066456755))

# %%
sns.boxplot(df_['health__pop_per_primary_care_physician'])

# %% [markdown]
# Dummy Variables

# %%
cat_columns = ['area__rucc','area__urban_influence','econ__economic_typology','yr']
for i in cat_columns:
    dummy = pd.get_dummies(df[i])
    df = pd.concat([df,dummy],axis=1)
    df.drop(i,axis=1,inplace=True)

# %%
df.corr()
# Out:
#                                                     econ__pct_civilian_labor  \
# econ__pct_civilian_labor                                            1.000000
# econ__pct_unemployment                                             -0.619050
# econ__pct_uninsured_adults                                         -0.406961
# econ__pct_uninsured_children                                       -0.027352
# demo__pct_female                                                    0.109445
# demo__pct_below_18_years_of_age                                    -0.014140
# demo__pct_aged_65_years_and_older                                   0.005079
# demo__pct_hispanic                                                  0.005111
# demo__pct_non_hispanic_african_american                            -0.344513
# demo__pct_non_hispanic_white                                        0.271294
# demo__pct_american_indian_or_alaskan_native                        -0.135626
# demo__pct_asian                                                     0.175724
# demo__pct_adults_less_than_a_high_school_diploma                   -0.520928
# demo__pct_adults_with_high_school_diploma                          -0.221864
# demo__pct_adults_with_some_college                                  0.239878
# demo__pct_adults_bachelors_or_higher                                0.432600
# demo__birth_rate_per_1k                                            -0.004480
# demo__death_rate_per_1k                                            -0.280318
# health__pct_adult_obesity                                          -0.368526
# health__pct_adult_smoking                                          -0.373734
# health__pct_diabetes                                               -0.498565
# health__pct_low_birthweight                                        -0.390125
# health__pct_excessive_drinking                                      0.295036
# health__pct_physical_inacticity                                    -0.344230
# health__air_pollution_particulate_matter                           -0.118307
# health__homicides_per_100k                                         -0.212742
# health__motor_vehicle_crash_deaths_per_100k                        -0.292637
# health__pop_per_dentist                                            -0.247269
# health__pop_per_primary_care_physician                             -0.200934
# heart_disease_mortality_per_100k                                   -0.476644
# Metro - Counties in metro areas of 1 million po...                  0.145408
# Metro - Counties in metro areas of 250,000 to 1...                 -0.002491
# Metro - Counties in metro areas of fewer than 2...                  0.008390
# Nonmetro - Completely rural or less than 2,500 ...                 -0.069309
# Nonmetro - Completely rural or less than 2,500 ...                  0.127341
# Nonmetro - Urban population of 2,500 to 19,999,...                 -0.127223
# Nonmetro - Urban population of 2,500 to 19,999,...                 -0.042908
# Nonmetro - Urban population of 20,000 or more, ...                 -0.040857
# Nonmetro - Urban population of 20,000 or more, ...                 -0.024709
# Large-in a metro area with at least 1 million r...                  0.145408
# Micropolitan adjacent to a large metro area                        -0.019620
# Micropolitan adjacent to a small metro area                        -0.080315
# Micropolitan not adjacent to a metro area                          -0.015972
# Noncore adjacent to a large metro area                             -0.012087
# Noncore adjacent to a small metro and does not ...                 -0.039088
# Noncore adjacent to a small metro with town of ...                 -0.132377
# Noncore adjacent to micro area and contains a t...                 -0.089216
# Noncore adjacent to micro area and does not con...                  0.073804
# Noncore not adjacent to a metro/micro area and ...                  0.066091
# Noncore not adjacent to a metro/micro area and ...                  0.089434
# Small-in a metro area with fewer than 1 million...                  0.004196
# Farm-dependent                                                      0.216222
# Federal/State government-dependent                                 -0.168377
# Manufacturing-dependent                                            -0.006935
# Mining-dependent                                                    0.034178
# Nonspecialized                                                     -0.068864
# Recreation                                                          0.015775
# a                                                                  -0.015326
# b                                                                   0.015326
#
#                                                     econ__pct_unemployment  \
# econ__pct_civilian_labor                                         -0.619050
# econ__pct_unemployment                                            1.000000
# econ__pct_uninsured_adults                                        0.271667
# econ__pct_uninsured_children                                     -0.104056
# demo__pct_female                                                  0.070929
# demo__pct_below_18_years_of_age                                   0.004798
# demo__pct_aged_65_years_and_older                                -0.049498
# demo__pct_hispanic                                               -0.024327
# demo__pct_non_hispanic_african_american                           0.381021
# demo__pct_non_hispanic_white                                     -0.318275
# demo__pct_american_indian_or_alaskan_native                       0.189726
# demo__pct_asian                                                  -0.089471
# demo__pct_adults_less_than_a_high_school_diploma                  0.417660
# demo__pct_adults_with_high_school_diploma                         0.188042
# demo__pct_adults_with_some_college                               -0.236731
# demo__pct_adults_bachelors_or_higher                             -0.328854
# demo__birth_rate_per_1k                                          -0.012124
# demo__death_rate_per_1k                                           0.190105
# health__pct_adult_obesity                                         0.291989
# health__pct_adult_smoking                                         0.327250
# health__pct_diabetes                                              0.420571
# health__pct_low_birthweight                                       0.362574
# health__pct_excessive_drinking                                   -0.176749
# health__pct_physical_inacticity                                   0.229787
# health__air_pollution_particulate_matter                          0.140900
# health__homicides_per_100k                                        0.276277
# health__motor_vehicle_crash_deaths_per_100k                       0.203483
# health__pop_per_dentist                                           0.165420
# health__pop_per_primary_care_physician                            0.136881
# heart_disease_mortality_per_100k                                  0.371620
# Metro - Counties in metro areas of 1 million po...               -0.079618
# Metro - Counties in metro areas of 250,000 to 1...               -0.017029
# Metro - Counties in metro areas of fewer than 2...               -0.005944
# Nonmetro - Completely rural or less than 2,500 ...                0.035584
# Nonmetro - Completely rural or less than 2,500 ...               -0.115493
# Nonmetro - Urban population of 2,500 to 19,999,...                0.100119
# Nonmetro - Urban population of 2,500 to 19,999,...                0.032180
# Nonmetro - Urban population of 20,000 or more, ...                0.067532
# Nonmetro - Urban population of 20,000 or more, ...               -0.003965
# Large-in a metro area with at least 1 million r...               -0.079618
# Micropolitan adjacent to a large metro area                       0.033224
# Micropolitan adjacent to a small metro area                       0.094943
# Micropolitan not adjacent to a metro area                        -0.005992
# Noncore adjacent to a large metro area                            0.019179
# Noncore adjacent to a small metro and does not ...                0.025784
# Noncore adjacent to a small metro with town of ...                0.074854
# Noncore adjacent to micro area and contains a t...                0.048829
# Noncore adjacent to micro area and does not con...               -0.084086
# Noncore not adjacent to a metro/micro area and ...               -0.030946
# Noncore not adjacent to a metro/micro area and ...               -0.059932
# Small-in a metro area with fewer than 1 million...               -0.017571
# Farm-dependent                                                   -0.294713
# Federal/State government-dependent                                0.104556
# Manufacturing-dependent                                           0.024851
# Mining-dependent                                                 -0.050648
# Nonspecialized                                                    0.104128
# Recreation                                                        0.084317
# a                                                                -0.150802
# b                                                                 0.150802
#
#                                                     econ__pct_uninsured_adults  \
# econ__pct_civilian_labor                                             -0.406961
# econ__pct_unemployment                                                0.271667
# econ__pct_uninsured_adults                                            1.000000
# econ__pct_uninsured_children                                          0.717686
# demo__pct_female                                                     -0.075923
# demo__pct_below_18_years_of_age                                       0.280156
# demo__pct_aged_65_years_and_older                                    -0.075758
# demo__pct_hispanic                                                    0.477867
# demo__pct_non_hispanic_african_american                               0.206044
# demo__pct_non_hispanic_white                                         -0.553043
# demo__pct_american_indian_or_alaskan_native                           0.244563
# demo__pct_asian                                                      -0.107376
# demo__pct_adults_less_than_a_high_school_diploma                      0.662628
# demo__pct_adults_with_high_school_diploma                             0.029713
# demo__pct_adults_with_some_college                                   -0.235526
# demo__pct_adults_bachelors_or_higher                                 -0.391570
# demo__birth_rate_per_1k                                               0.283757
# demo__death_rate_per_1k                                               0.060453
# health__pct_adult_obesity                                             0.180362
# health__pct_adult_smoking                                             0.228772
# health__pct_diabetes                                                  0.294417
# health__pct_low_birthweight                                           0.319276
# health__pct_excessive_drinking                                       -0.271418
# health__pct_physical_inacticity                                       0.285383
# health__air_pollution_particulate_matter                             -0.220341
# health__homicides_per_100k                                            0.243690
# health__motor_vehicle_crash_deaths_per_100k                           0.413753
# health__pop_per_dentist                                               0.228149
# health__pop_per_primary_care_physician                                0.155343
# heart_disease_mortality_per_100k                                      0.333963
# Metro - Counties in metro areas of 1 million po...                   -0.178095
# Metro - Counties in metro areas of 250,000 to 1...                   -0.065414
# Metro - Counties in metro areas of fewer than 2...                   -0.052398
# Nonmetro - Completely rural or less than 2,500 ...                    0.031122
# Nonmetro - Completely rural or less than 2,500 ...                    0.068523
# Nonmetro - Urban population of 2,500 to 19,999,...                    0.093186
# Nonmetro - Urban population of 2,500 to 19,999,...                    0.101851
# Nonmetro - Urban population of 20,000 or more, ...                   -0.043466
# Nonmetro - Urban population of 20,000 or more, ...                    0.030038
# Large-in a metro area with at least 1 million r...                   -0.178095
# Micropolitan adjacent to a large metro area                          -0.013687
# Micropolitan adjacent to a small metro area                           0.014050
# Micropolitan not adjacent to a metro area                             0.030544
# Noncore adjacent to a large metro area                               -0.003089
# Noncore adjacent to a small metro and does not ...                    0.030619
# Noncore adjacent to a small metro with town of ...                    0.084291
# Noncore adjacent to micro area and contains a t...                    0.098063
# Noncore adjacent to micro area and does not con...                    0.036913
# Noncore not adjacent to a metro/micro area and ...                    0.035530
# Noncore not adjacent to a metro/micro area and ...                    0.063929
# Small-in a metro area with fewer than 1 million...                   -0.089104
# Farm-dependent                                                        0.026725
# Federal/State government-dependent                                    0.016540
# Manufacturing-dependent                                              -0.041864
# Mining-dependent                                                      0.166709
# Nonspecialized                                                       -0.056668
# Recreation                                                           -0.057998
# a                                                                    -0.030735
# b                                                                     0.030735
#
#                                                     econ__pct_uninsured_children  \
# econ__pct_civilian_labor                                               -0.027352
# econ__pct_unemployment                                                 -0.104056
# econ__pct_uninsured_adults                                              0.717686
# econ__pct_uninsured_children                                            1.000000
# demo__pct_female                                                       -0.210481
# demo__pct_below_18_years_of_age                                         0.183530
# demo__pct_aged_65_years_and_older                                       0.083595
# demo__pct_hispanic                                                      0.441552
# demo__pct_non_hispanic_african_american                                -0.102593
# demo__pct_non_hispanic_white                                           -0.296403
# demo__pct_american_indian_or_alaskan_native                             0.203004
# demo__pct_asian                                                        -0.088977
# demo__pct_adults_less_than_a_high_school_diploma                        0.281704
# demo__pct_adults_with_high_school_diploma                              -0.079471
# demo__pct_adults_with_some_college                                      0.040214
# demo__pct_adults_bachelors_or_higher                                   -0.175922
# demo__birth_rate_per_1k                                                 0.161230
# demo__death_rate_per_1k                                                -0.049201
# health__pct_adult_obesity                                              -0.128264
# health__pct_adult_smoking                                               0.004146
# health__pct_diabetes                                                   -0.055636
# health__pct_low_birthweight                                             0.021829
# health__pct_excessive_drinking                                         -0.032526
# health__pct_physical_inacticity                                         0.009911
# health__air_pollution_particulate_matter                               -0.345975
# health__homicides_per_100k                                              0.016972
# health__motor_vehicle_crash_deaths_per_100k                             0.340927
# health__pop_per_dentist                                                 0.142384
# health__pop_per_primary_care_physician                                  0.077711
# heart_disease_mortality_per_100k                                       -0.034456
# Metro - Counties in metro areas of 1 million po...                     -0.144008
# Metro - Counties in metro areas of 250,000 to 1...                     -0.124191
# Metro - Counties in metro areas of fewer than 2...                     -0.077764
# Nonmetro - Completely rural or less than 2,500 ...                      0.098203
# Nonmetro - Completely rural or less than 2,500 ...                      0.263016
# Nonmetro - Urban population of 2,500 to 19,999,...                     -0.021186
# Nonmetro - Urban population of 2,500 to 19,999,...                      0.075435
# Nonmetro - Urban population of 20,000 or more, ...                     -0.073667
# Nonmetro - Urban population of 20,000 or more, ...                     -0.033818
# Large-in a metro area with at least 1 million r...                     -0.144008
# Micropolitan adjacent to a large metro area                            -0.030084
# Micropolitan adjacent to a small metro area                            -0.052890
# Micropolitan not adjacent to a metro area                              -0.024681
# Noncore adjacent to a large metro area                                  0.019358
# Noncore adjacent to a small metro and does not ...                      0.076259
# Noncore adjacent to a small metro with town of ...                     -0.008019
# Noncore adjacent to micro area and contains a t...                      0.063325
# Noncore adjacent to micro area and does not con...                      0.155111
# Noncore not adjacent to a metro/micro area and ...                      0.080567
# Noncore not adjacent to a metro/micro area and ...                      0.206208
# Small-in a metro area with fewer than 1 million...                     -0.153297
# Farm-dependent                                                          0.233468
# Federal/State government-dependent                                     -0.009986
# Manufacturing-dependent                                                -0.111966
# Mining-dependent                                                        0.221990
# Nonspecialized                                                         -0.221252
# Recreation                                                              0.028235
# a                                                                      -0.050645
# b                                                                       0.050645
#
#                                                     demo__pct_female  \
# econ__pct_civilian_labor                                    0.109445
# econ__pct_unemployment                                      0.070929
# econ__pct_uninsured_adults                                 -0.075923
# econ__pct_uninsured_children                               -0.210481
# demo__pct_female                                            1.000000
# demo__pct_below_18_years_of_age                             0.198426
# demo__pct_aged_65_years_and_older                           0.106818
# demo__pct_hispanic                                         -0.161762
# demo__pct_non_hispanic_african_american                     0.098043
# demo__pct_non_hispanic_white                                0.066155
# demo__pct_american_indian_or_alaskan_native                -0.067176
# demo__pct_asian                                             0.011123
# demo__pct_adults_less_than_a_high_school_diploma           -0.132730
# demo__pct_adults_with_high_school_diploma                  -0.105586
# demo__pct_adults_with_some_college                          0.011703
# demo__pct_adults_bachelors_or_higher                        0.177928
# demo__birth_rate_per_1k                                     0.105897
# demo__death_rate_per_1k                                     0.183062
# health__pct_adult_obesity                                   0.042139
# health__pct_adult_smoking                                  -0.050735
# health__pct_diabetes                                        0.189265
# health__pct_low_birthweight                                 0.070758
# health__pct_excessive_drinking                             -0.144424
# health__pct_physical_inacticity                             0.068177
# health__air_pollution_particulate_matter                    0.111823
# health__homicides_per_100k                                  0.105499
# health__motor_vehicle_crash_deaths_per_100k                -0.068367
# health__pop_per_dentist                                    -0.121884
# health__pop_per_primary_care_physician                     -0.105135
# heart_disease_mortality_per_100k                            0.086974
# Metro - Counties in metro areas of 1 million po...          0.109128
# Metro - Counties in metro areas of 250,000 to 1...          0.096648
# Metro - Counties in metro areas of fewer than 2...          0.065574
# Nonmetro - Completely rural or less than 2,500 ...         -0.079091
# Nonmetro - Completely rural or less than 2,500 ...         -0.138018
# Nonmetro - Urban population of 2,500 to 19,999,...         -0.003657
# Nonmetro - Urban population of 2,500 to 19,999,...         -0.090602
# Nonmetro - Urban population of 20,000 or more, ...          0.038089
# Nonmetro - Urban population of 20,000 or more, ...          0.025411
# Large-in a metro area with at least 1 million r...          0.109128
# Micropolitan adjacent to a large metro area                 0.032351
# Micropolitan adjacent to a small metro area                 0.038084
# Micropolitan not adjacent to a metro area                  -0.040633
# Noncore adjacent to a large metro area                     -0.025860
# Noncore adjacent to a small metro and does not ...         -0.064696
# Noncore adjacent to a small metro with town of ...         -0.028626
# Noncore adjacent to micro area and contains a t...         -0.072494
# Noncore adjacent to micro area and does not con...         -0.075951
# Noncore not adjacent to a metro/micro area and ...         -0.102070
# Noncore not adjacent to a metro/micro area and ...         -0.034041
# Small-in a metro area with fewer than 1 million...          0.122993
# Farm-dependent                                             -0.050917
# Federal/State government-dependent                         -0.246781
# Manufacturing-dependent                                     0.074345
# Mining-dependent                                           -0.137271
# Nonspecialized                                              0.213960
# Recreation                                                  0.015456
# a                                                          -0.018938
# b                                                           0.018938
#
#                                                     demo__pct_below_18_years_of_age  \
# econ__pct_civilian_labor                                                  -0.014140
# econ__pct_unemployment                                                     0.004798
# econ__pct_uninsured_adults                                                 0.280156
# econ__pct_uninsured_children                                               0.183530
# demo__pct_female                                                           0.198426
# demo__pct_below_18_years_of_age                                            1.000000
# demo__pct_aged_65_years_and_older                                         -0.566433
# demo__pct_hispanic                                                         0.320594
# demo__pct_non_hispanic_african_american                                    0.021927
# demo__pct_non_hispanic_white                                              -0.372009
# demo__pct_american_indian_or_alaskan_native                                0.338910
# demo__pct_asian                                                            0.017483
# demo__pct_adults_less_than_a_high_school_diploma                           0.220496
# demo__pct_adults_with_high_school_diploma                                 -0.115810
# demo__pct_adults_with_some_college                                         0.043559
# demo__pct_adults_bachelors_or_higher                                      -0.102427
# demo__birth_rate_per_1k                                                    0.729287
# demo__death_rate_per_1k                                                   -0.299635
# health__pct_adult_obesity                                                  0.170959
# health__pct_adult_smoking                                                 -0.000935
# health__pct_diabetes                                                      -0.039540
# health__pct_low_birthweight                                               -0.033572
# health__pct_excessive_drinking                                            -0.103581
# health__pct_physical_inacticity                                            0.061171
# health__air_pollution_particulate_matter                                  -0.114623
# health__homicides_per_100k                                                 0.090877
# health__motor_vehicle_crash_deaths_per_100k                                0.122421
# health__pop_per_dentist                                                    0.009023
# health__pop_per_primary_care_physician                                     0.064456
# heart_disease_mortality_per_100k                                           0.121863
# Metro - Counties in metro areas of 1 million po...                         0.091650
# Metro - Counties in metro areas of 250,000 to 1...                         0.062521
# Metro - Counties in metro areas of fewer than 2...                        -0.020113
# Nonmetro - Completely rural or less than 2,500 ...                        -0.140371
# Nonmetro - Completely rural or less than 2,500 ...                        -0.103624
# Nonmetro - Urban population of 2,500 to 19,999,...                         0.037519
# Nonmetro - Urban population of 2,500 to 19,999,...                         0.037824
# Nonmetro - Urban population of 20,000 or more, ...                        -0.026415
# Nonmetro - Urban population of 20,000 or more, ...                         0.044960
# Large-in a metro area with at least 1 million r...                         0.091650
# Micropolitan adjacent to a large metro area                               -0.002537
# Micropolitan adjacent to a small metro area                                0.029969
# Micropolitan not adjacent to a metro area                                  0.019722
# Noncore adjacent to a large metro area                                    -0.046107
# Noncore adjacent to a small metro and does not ...                        -0.095231
# Noncore adjacent to a small metro with town of ...                        -0.015611
# Noncore adjacent to micro area and contains a t...                         0.024523
# Noncore adjacent to micro area and does not con...                        -0.070114
# Noncore not adjacent to a metro/micro area and ...                         0.011518
# Noncore not adjacent to a metro/micro area and ...                        -0.051494
# Small-in a metro area with fewer than 1 million...                         0.033868
# Farm-dependent                                                             0.003989
# Federal/State government-dependent                                        -0.135081
# Manufacturing-dependent                                                    0.086554
# Mining-dependent                                                           0.098221
# Nonspecialized                                                             0.137691
# Recreation                                                                -0.277703
# a                                                                         -0.021655
# b                                                                          0.021655
#
#                                                     demo__pct_aged_65_years_and_older  \
# econ__pct_civilian_labor                                                     0.005079
# econ__pct_unemployment                                                      -0.049498
# econ__pct_uninsured_adults                                                  -0.075758
# econ__pct_uninsured_children                                                 0.083595
# demo__pct_female                                                             0.106818
# demo__pct_below_18_years_of_age                                             -0.566433
# demo__pct_aged_65_years_and_older                                            1.000000
# demo__pct_hispanic                                                          -0.245151
# demo__pct_non_hispanic_african_american                                     -0.224977
# demo__pct_non_hispanic_white                                                 0.443333
# demo__pct_american_indian_or_alaskan_native                                 -0.174039
# demo__pct_asian                                                             -0.318529
# demo__pct_adults_less_than_a_high_school_diploma                            -0.141298
# demo__pct_adults_with_high_school_diploma                                    0.303597
# demo__pct_adults_with_some_college                                           0.135038
# demo__pct_adults_bachelors_or_higher                                        -0.211036
# demo__birth_rate_per_1k                                                     -0.518372
# demo__death_rate_per_1k                                                      0.639432
# health__pct_adult_obesity                                                   -0.035280
# health__pct_adult_smoking                                                    0.034272
# health__pct_diabetes                                                         0.213014
# health__pct_low_birthweight                                                 -0.070468
# health__pct_excessive_drinking                                               0.058010
# health__pct_physical_inacticity                                              0.164289
# health__air_pollution_particulate_matter                                    -0.066530
# health__homicides_per_100k                                                  -0.107770
# health__motor_vehicle_crash_deaths_per_100k                                  0.183806
# health__pop_per_dentist                                                      0.049423
# health__pop_per_primary_care_physician                                      -0.017388
# heart_disease_mortality_per_100k                                            -0.056160
# Metro - Counties in metro areas of 1 million po...                          -0.291838
# Metro - Counties in metro areas of 250,000 to 1...                          -0.150241
# Metro - Counties in metro areas of fewer than 2...                          -0.103784
# Nonmetro - Completely rural or less than 2,500 ...                           0.183668
# Nonmetro - Completely rural or less than 2,500 ...                           0.333535
# Nonmetro - Urban population of 2,500 to 19,999,...                           0.045027
# Nonmetro - Urban population of 2,500 to 19,999,...                           0.025594
# Nonmetro - Urban population of 20,000 or more, ...                          -0.014834
# Nonmetro - Urban population of 20,000 or more, ...                          -0.062254
# Large-in a metro area with at least 1 million r...                          -0.291838
# Micropolitan adjacent to a large metro area                                  0.008448
# Micropolitan adjacent to a small metro area                                 -0.041309
# Micropolitan not adjacent to a metro area                                   -0.043344
# Noncore adjacent to a large metro area                                       0.057921
# Noncore adjacent to a small metro and does not ...                           0.140196
# Noncore adjacent to a small metro with town of ...                           0.087775
# Noncore adjacent to micro area and contains a t...                           0.052500
# Noncore adjacent to micro area and does not con...                           0.219910
# Noncore not adjacent to a metro/micro area and ...                          -0.010027
# Noncore not adjacent to a metro/micro area and ...                           0.256795
# Small-in a metro area with fewer than 1 million...                          -0.192546
# Farm-dependent                                                               0.327599
# Federal/State government-dependent                                          -0.159108
# Manufacturing-dependent                                                     -0.058608
# Mining-dependent                                                            -0.090396
# Nonspecialized                                                              -0.202503
# Recreation                                                                   0.267975
# a                                                                            0.044749
# b                                                                           -0.044749
#
#                                                     demo__pct_hispanic  \
# econ__pct_civilian_labor                                      0.005111
# econ__pct_unemployment                                       -0.024327
# econ__pct_uninsured_adults                                    0.477867
# econ__pct_uninsured_children                                  0.441552
# demo__pct_female                                             -0.161762
# demo__pct_below_18_years_of_age                               0.320594
# demo__pct_aged_65_years_and_older                            -0.245151
# demo__pct_hispanic                                            1.000000
# demo__pct_non_hispanic_african_american                      -0.105763
# demo__pct_non_hispanic_white                                 -0.606456
# demo__pct_american_indian_or_alaskan_native                  -0.014103
# demo__pct_asian                                               0.170282
# demo__pct_adults_less_than_a_high_school_diploma              0.437399
# demo__pct_adults_with_high_school_diploma                    -0.317491
# demo__pct_adults_with_some_college                           -0.100493
# demo__pct_adults_bachelors_or_higher                         -0.024366
# demo__birth_rate_per_1k                                       0.305239
# demo__death_rate_per_1k                                      -0.295777
# health__pct_adult_obesity                                    -0.246203
# health__pct_adult_smoking                                    -0.149604
# health__pct_diabetes                                         -0.252558
# health__pct_low_birthweight                                  -0.004974
# health__pct_excessive_drinking                               -0.021463
# health__pct_physical_inacticity                              -0.215256
# health__air_pollution_particulate_matter                     -0.390688
# health__homicides_per_100k                                   -0.013698
# health__motor_vehicle_crash_deaths_per_100k                  -0.048889
# health__pop_per_dentist                                       0.032643
# health__pop_per_primary_care_physician                       -0.002935
# heart_disease_mortality_per_100k                             -0.111856
# Metro - Counties in metro areas of 1 million po...            0.063672
# Metro - Counties in metro areas of 250,000 to 1...           -0.023963
# Metro - Counties in metro areas of fewer than 2...           -0.037575
# Nonmetro - Completely rural or less than 2,500 ...           -0.076705
# Nonmetro - Completely rural or less than 2,500 ...           -0.041945
# Nonmetro - Urban population of 2,500 to 19,999,...            0.017173
# Nonmetro - Urban population of 2,500 to 19,999,...            0.061742
# Nonmetro - Urban population of 20,000 or more, ...           -0.002888
# Nonmetro - Urban population of 20,000 or more, ...            0.031433
# Large-in a metro area with at least 1 million r...            0.063672
# Micropolitan adjacent to a large metro area                  -0.013645
# Micropolitan adjacent to a small metro area                   0.044618
# Micropolitan not adjacent to a metro area                     0.033198
# Noncore adjacent to a large metro area                       -0.028125
# Noncore adjacent to a small metro and does not ...           -0.069733
# Noncore adjacent to a small metro with town of ...           -0.005510
# Noncore adjacent to micro area and contains a t...            0.037439
# Noncore adjacent to micro area and does not con...           -0.036845
# Noncore not adjacent to a metro/micro area and ...            0.042566
# Noncore not adjacent to a metro/micro area and ...           -0.024000
# Small-in a metro area with fewer than 1 million...           -0.046073
# Farm-dependent                                               -0.005795
# Federal/State government-dependent                            0.060029
# Manufacturing-dependent                                      -0.080233
# Mining-dependent                                              0.206279
# Nonspecialized                                               -0.049893
# Recreation                                                   -0.067242
# a                                                             0.013154
# b                                                            -0.013154
#
#                                                     demo__pct_non_hispanic_african_american  \
# econ__pct_civilian_labor                                                          -0.344513
# econ__pct_unemployment                                                             0.381021
# econ__pct_uninsured_adults                                                         0.206044
# econ__pct_uninsured_children                                                      -0.102593
# demo__pct_female                                                                   0.098043
# demo__pct_below_18_years_of_age                                                    0.021927
# demo__pct_aged_65_years_and_older                                                 -0.224977
# demo__pct_hispanic                                                                -0.105763
# demo__pct_non_hispanic_african_american                                            1.000000
# demo__pct_non_hispanic_white                                                      -0.593917
# demo__pct_american_indian_or_alaskan_native                                       -0.102409
# demo__pct_asian                                                                    0.021610
# demo__pct_adults_less_than_a_high_school_diploma                                   0.353863
# demo__pct_adults_with_high_school_diploma                                         -0.045702
# demo__pct_adults_with_some_college                                                -0.254705
# demo__pct_adults_bachelors_or_higher                                              -0.084942
# demo__birth_rate_per_1k                                                            0.066381
# demo__death_rate_per_1k                                                            0.029745
# health__pct_adult_obesity                                                          0.407626
# health__pct_adult_smoking                                                          0.023534
# health__pct_diabetes                                                               0.486475
# health__pct_low_birthweight                                                        0.674358
# health__pct_excessive_drinking                                                    -0.227960
# health__pct_physical_inacticity                                                    0.257012
# health__air_pollution_particulate_matter                                           0.167891
# health__homicides_per_100k                                                         0.551476
# health__motor_vehicle_crash_deaths_per_100k                                        0.103010
# health__pop_per_dentist                                                            0.140313
# health__pop_per_primary_care_physician                                             0.109200
# heart_disease_mortality_per_100k                                                   0.375658
# Metro - Counties in metro areas of 1 million po...                                 0.089127
# Metro - Counties in metro areas of 250,000 to 1...                                 0.051048
# Metro - Counties in metro areas of fewer than 2...                                -0.002794
# Nonmetro - Completely rural or less than 2,500 ...                                 0.057391
# Nonmetro - Completely rural or less than 2,500 ...                                -0.162428
# Nonmetro - Urban population of 2,500 to 19,999,...                                 0.035613
# Nonmetro - Urban population of 2,500 to 19,999,...                                -0.045203
# Nonmetro - Urban population of 20,000 or more, ...                                -0.006277
# Nonmetro - Urban population of 20,000 or more, ...                                -0.000366
# Large-in a metro area with at least 1 million r...                                 0.089127
# Micropolitan adjacent to a large metro area                                       -0.007251
# Micropolitan adjacent to a small metro area                                        0.003819
# Micropolitan not adjacent to a metro area                                         -0.014159
# Noncore adjacent to a large metro area                                             0.020260
# Noncore adjacent to a small metro and does not ...                                 0.016310
# Noncore adjacent to a small metro with town of ...                                 0.063403
# Noncore adjacent to micro area and contains a t...                                 0.013448
# Noncore adjacent to micro area and does not con...                                -0.100466
# Noncore not adjacent to a metro/micro area and ...                                -0.078069
# Noncore not adjacent to a metro/micro area and ...                                -0.133813
# Small-in a metro area with fewer than 1 million...                                 0.037611
# Farm-dependent                                                                    -0.177658
# Federal/State government-dependent                                                 0.117193
# Manufacturing-dependent                                                            0.003195
# Mining-dependent                                                                  -0.085967
# Nonspecialized                                                                     0.171579
# Recreation                                                                        -0.123366
# a                                                                                  0.001904
# b                                                                                 -0.001904
#
#                                                     demo__pct_non_hispanic_white  \
# econ__pct_civilian_labor                                                0.271294
# econ__pct_unemployment                                                 -0.318275
# econ__pct_uninsured_adults                                             -0.553043
# econ__pct_uninsured_children                                           -0.296403
# demo__pct_female                                                        0.066155
# demo__pct_below_18_years_of_age                                        -0.372009
# demo__pct_aged_65_years_and_older                                       0.443333
# demo__pct_hispanic                                                     -0.606456
# demo__pct_non_hispanic_african_american                                -0.593917
# demo__pct_non_hispanic_white                                            1.000000
# demo__pct_american_indian_or_alaskan_native                            -0.330831
# demo__pct_asian                                                        -0.255769
# demo__pct_adults_less_than_a_high_school_diploma                       -0.528151
# demo__pct_adults_with_high_school_diploma                               0.310105
# demo__pct_adults_with_some_college                                      0.210029
# demo__pct_adults_bachelors_or_higher                                    0.035343
# demo__birth_rate_per_1k                                                -0.411388
# demo__death_rate_per_1k                                                 0.254080
# health__pct_adult_obesity                                              -0.132844
# health__pct_adult_smoking                                               0.034881
# health__pct_diabetes                                                   -0.157388
# health__pct_low_birthweight                                            -0.408669
# health__pct_excessive_drinking                                          0.133432
# health__pct_physical_inacticity                                        -0.001750
# health__air_pollution_particulate_matter                                0.228772
# health__homicides_per_100k                                             -0.408480
# health__motor_vehicle_crash_deaths_per_100k                            -0.105694
# health__pop_per_dentist                                                -0.054411
# health__pop_per_primary_care_physician                                 -0.039439
# heart_disease_mortality_per_100k                                       -0.157424
# Metro - Counties in metro areas of 1 million po...                     -0.123528
# Metro - Counties in metro areas of 250,000 to 1...                     -0.010903
# Metro - Counties in metro areas of fewer than 2...                      0.034811
# Nonmetro - Completely rural or less than 2,500 ...                      0.028414
# Nonmetro - Completely rural or less than 2,500 ...                      0.114168
# Nonmetro - Urban population of 2,500 to 19,999,...                     -0.009134
# Nonmetro - Urban population of 2,500 to 19,999,...                     -0.026909
# Nonmetro - Urban population of 20,000 or more, ...                      0.019225
# Nonmetro - Urban population of 20,000 or more, ...                     -0.029904
# Large-in a metro area with at least 1 million r...                     -0.123528
# Micropolitan adjacent to a large metro area                             0.032513
# ...
# health__pct_diabetes                                   -2.416996e-02
# health__pct_low_birthweight                             5.222292e-02
# health__pct_excessive_drinking                         -3.473195e-02
# health__pct_physical_inacticity                         8.434342e-02
# health__air_pollution_particulate_matter               -1.442369e-01
# health__homicides_per_100k                             -1.050895e-02
# health__motor_vehicle_crash_deaths_per_100k             1.935604e-01
# health__pop_per_dentist                                 6.528902e-02
# health__pop_per_primary_care_physician                  4.522516e-02
# heart_disease_mortality_per_100k                        1.092417e-01
# Metro - Counties in metro areas of 1 million po...     -7.626157e-02
# Metro - Counties in metro areas of 250,000 to 1...     -6.286077e-02
# Metro - Counties in metro areas of fewer than 2...     -1.373770e-02
# Nonmetro - Completely rural or less than 2,500 ...     -3.979029e-03
# Nonmetro - Completely rural or less than 2,500 ...      4.374978e-02
# Nonmetro - Urban population of 2,500 to 19,999,...      5.038962e-03
# Nonmetro - Urban population of 2,500 to 19,999,...      1.331127e-01
# Nonmetro - Urban population of 20,000 or more, ...     -2.562614e-02
# Nonmetro - Urban population of 20,000 or more, ...     -2.619508e-02
# Large-in a metro area with at least 1 million r...     -7.626157e-02
# Micropolitan adjacent to a large metro area            -4.759858e-02
# Micropolitan adjacent to a small metro area            -1.184555e-02
# Micropolitan not adjacent to a metro area               2.491655e-02
# Noncore adjacent to a large metro area                 -2.930039e-03
# Noncore adjacent to a small metro and does not ...      3.053351e-02
# Noncore adjacent to a small metro with town of ...      1.932456e-03
# Noncore adjacent to micro area and contains a t...      7.366718e-02
# Noncore adjacent to micro area and does not con...      4.351582e-02
# Noncore not adjacent to a metro/micro area and ...      7.431637e-02
# Noncore not adjacent to a metro/micro area and ...      2.484115e-02
# Small-in a metro area with fewer than 1 million...     -5.886793e-02
# Farm-dependent                                         -1.237390e-01
# Federal/State government-dependent                     -1.094666e-01
# Manufacturing-dependent                                -1.255475e-01
# Mining-dependent                                        1.000000e+00
# Nonspecialized                                         -2.377723e-01
# Recreation                                             -9.657775e-02
# a                                                      -4.159772e-17
# b                                                       4.159772e-17
#
#                                                     Nonspecialized  \
# econ__pct_civilian_labor                             -6.886362e-02
# econ__pct_unemployment                                1.041276e-01
# econ__pct_uninsured_adults                           -5.666842e-02
# econ__pct_uninsured_children                         -2.212523e-01
# demo__pct_female                                      2.139599e-01
# demo__pct_below_18_years_of_age                       1.376906e-01
# demo__pct_aged_65_years_and_older                    -2.025031e-01
# demo__pct_hispanic                                   -4.989323e-02
# demo__pct_non_hispanic_african_american               1.715789e-01
# demo__pct_non_hispanic_white                         -7.980352e-02
# demo__pct_american_indian_or_alaskan_native          -6.748174e-02
# demo__pct_asian                                       1.350654e-01
# demo__pct_adults_less_than_a_high_school_diploma     -6.476018e-03
# demo__pct_adults_with_high_school_diploma            -7.693708e-02
# demo__pct_adults_with_some_college                   -7.057960e-02
# demo__pct_adults_bachelors_or_higher                  1.070732e-01
# demo__birth_rate_per_1k                               7.912096e-02
# demo__death_rate_per_1k                              -3.838359e-02
# health__pct_adult_obesity                             6.497589e-02
# health__pct_adult_smoking                             2.597923e-02
# health__pct_diabetes                                  6.654575e-02
# health__pct_low_birthweight                           1.078053e-01
# health__pct_excessive_drinking                       -1.244560e-01
# health__pct_physical_inacticity                       4.448751e-03
# health__air_pollution_particulate_matter              1.094195e-01
# health__homicides_per_100k                            5.957479e-02
# health__motor_vehicle_crash_deaths_per_100k          -1.448433e-01
# health__pop_per_dentist                              -7.534145e-02
# health__pop_per_primary_care_physician               -8.466051e-02
# heart_disease_mortality_per_100k                      1.042410e-01
# Metro - Counties in metro areas of 1 million po...    2.224877e-01
# Metro - Counties in metro areas of 250,000 to 1...    1.189962e-01
# Metro - Counties in metro areas of fewer than 2...    2.662287e-02
# Nonmetro - Completely rural or less than 2,500 ...   -9.310811e-02
# Nonmetro - Completely rural or less than 2,500 ...   -2.490708e-01
# Nonmetro - Urban population of 2,500 to 19,999,...   -1.416112e-02
# Nonmetro - Urban population of 2,500 to 19,999,...   -4.452942e-02
# Nonmetro - Urban population of 20,000 or more, ...    3.551294e-02
# Nonmetro - Urban population of 20,000 or more, ...    1.621166e-02
# Large-in a metro area with at least 1 million r...    2.224877e-01
# Micropolitan adjacent to a large metro area           4.640868e-02
# Micropolitan adjacent to a small metro area           3.795962e-02
# Micropolitan not adjacent to a metro area            -2.495114e-02
# Noncore adjacent to a large metro area               -2.522024e-02
# Noncore adjacent to a small metro and does not ...   -1.112386e-01
# Noncore adjacent to a small metro with town of ...   -3.081917e-02
# Noncore adjacent to micro area and contains a t...   -4.571027e-02
# Noncore adjacent to micro area and does not con...   -1.578103e-01
# Noncore not adjacent to a metro/micro area and ...   -7.665477e-03
# Noncore not adjacent to a metro/micro area and ...   -1.732988e-01
# Small-in a metro area with fewer than 1 million...    1.118887e-01
# Farm-dependent                                       -3.410138e-01
# Federal/State government-dependent                   -3.016804e-01
# Manufacturing-dependent                              -3.459979e-01
# Mining-dependent                                     -2.377723e-01
# Nonspecialized                                        1.000000e+00
# Recreation                                           -2.661598e-01
# a                                                     5.040205e-18
# b                                                    -5.040205e-18
#
#                                                       Recreation  \
# econ__pct_civilian_labor                            1.577456e-02
# econ__pct_unemployment                              8.431749e-02
# econ__pct_uninsured_adults                         -5.799819e-02
# econ__pct_uninsured_children                        2.823508e-02
# demo__pct_female                                    1.545612e-02
# demo__pct_below_18_years_of_age                    -2.777026e-01
# demo__pct_aged_65_years_and_older                   2.679753e-01
# demo__pct_hispanic                                 -6.724170e-02
# demo__pct_non_hispanic_african_american            -1.233662e-01
# demo__pct_non_hispanic_white                        1.340957e-01
# demo__pct_american_indian_or_alaskan_native        -1.414353e-02
# demo__pct_asian                                    -1.725819e-02
# demo__pct_adults_less_than_a_high_school_diploma   -2.018477e-01
# demo__pct_adults_with_high_school_diploma          -1.166011e-01
# demo__pct_adults_with_some_college                  1.128562e-01
# demo__pct_adults_bachelors_or_higher                1.801605e-01
# demo__birth_rate_per_1k                            -2.597847e-01
# demo__death_rate_per_1k                             1.552885e-02
# health__pct_adult_obesity                          -2.515603e-01
# health__pct_adult_smoking                          -4.639446e-02
# health__pct_diabetes                               -9.873405e-02
# health__pct_low_birthweight                        -1.281902e-01
# health__pct_excessive_drinking                      1.156430e-01
# health__pct_physical_inacticity                    -2.543582e-01
# health__air_pollution_particulate_matter           -5.062804e-02
# health__homicides_per_100k                         -8.831296e-02
# health__motor_vehicle_crash_deaths_per_100k        -8.877359e-02
# health__pop_per_dentist                            -7.244727e-02
# health__pop_per_primary_care_physician             -8.489671e-02
# heart_disease_mortality_per_100k                   -2.259540e-01
# Metro - Counties in metro areas of 1 million po... -1.647922e-03
# Metro - Counties in metro areas of 250,000 to 1... -3.214316e-04
# Metro - Counties in metro areas of fewer than 2... -3.297115e-02
# Nonmetro - Completely rural or less than 2,500 ...  1.919512e-02
# Nonmetro - Completely rural or less than 2,500 ... -3.586010e-03
# Nonmetro - Urban population of 2,500 to 19,999,... -3.039383e-02
# Nonmetro - Urban population of 2,500 to 19,999,...  2.257097e-02
# Nonmetro - Urban population of 20,000 or more, ...  4.287874e-02
# Nonmetro - Urban population of 20,000 or more, ...  1.476823e-03
# Large-in a metro area with at least 1 million r... -1.647922e-03
# Micropolitan adjacent to a large metro area         2.008246e-02
# Micropolitan adjacent to a small metro area        -2.136856e-02
# Micropolitan not adjacent to a metro area           4.752842e-03
# Noncore adjacent to a large metro area              3.202341e-02
# Noncore adjacent to a small metro and does not ...  3.155903e-02
# Noncore adjacent to a small metro with town of ... -2.631379e-02
# Noncore adjacent to micro area and contains a t... -1.758993e-02
# Noncore adjacent to micro area and does not con...  1.494279e-02
# Noncore not adjacent to a metro/micro area and ...  2.254267e-02
# Noncore not adjacent to a metro/micro area and ...  6.433701e-03
# Small-in a metro area with fewer than 1 million... -2.434390e-02
# Farm-dependent                                     -1.385121e-01
# Federal/State government-dependent                 -1.225358e-01
# Manufacturing-dependent                            -1.405365e-01
# Mining-dependent                                   -9.657775e-02
# Nonspecialized                                     -2.661598e-01
# Recreation                                          1.000000e+00
# a                                                  -2.486244e-18
# b                                                   2.486244e-18
#
#                                                                a             b
# econ__pct_civilian_labor                           -1.532624e-02  1.532624e-02
# econ__pct_unemployment                             -1.508019e-01  1.508019e-01
# econ__pct_uninsured_adults                         -3.073513e-02  3.073513e-02
# econ__pct_uninsured_children                       -5.064531e-02  5.064531e-02
# demo__pct_female                                   -1.893782e-02  1.893782e-02
# demo__pct_below_18_years_of_age                    -2.165481e-02  2.165481e-02
# demo__pct_aged_65_years_and_older                   4.474858e-02 -4.474858e-02
# demo__pct_hispanic                                  1.315358e-02 -1.315358e-02
# demo__pct_non_hispanic_african_american             1.904476e-03 -1.904476e-03
# demo__pct_non_hispanic_white                       -1.551947e-02  1.551947e-02
# demo__pct_american_indian_or_alaskan_native         3.447854e-03 -3.447854e-03
# demo__pct_asian                                     1.307529e-02 -1.307529e-02
# demo__pct_adults_less_than_a_high_school_diploma   -1.135519e-03  1.135519e-03
# demo__pct_adults_with_high_school_diploma           1.422708e-03 -1.422708e-03
# demo__pct_adults_with_some_college                  7.141198e-04 -7.141198e-04
# demo__pct_adults_bachelors_or_higher               -6.750551e-04  6.750551e-04
# demo__birth_rate_per_1k                            -6.050502e-03  6.050502e-03
# demo__death_rate_per_1k                            -8.070768e-02  8.070768e-02
# health__pct_adult_obesity                           1.987298e-02 -1.987298e-02
# health__pct_adult_smoking                           2.248021e-03 -2.248021e-03
# health__pct_diabetes                                5.863121e-02 -5.863121e-02
# health__pct_low_birthweight                        -3.202797e-02  3.202797e-02
# health__pct_excessive_drinking                      7.288599e-04 -7.288599e-04
# health__pct_physical_inacticity                    -7.706062e-02  7.706062e-02
# health__air_pollution_particulate_matter            4.029550e-04 -4.029550e-04
# health__homicides_per_100k                          3.534075e-03 -3.534075e-03
# health__motor_vehicle_crash_deaths_per_100k        -6.955435e-02  6.955435e-02
# health__pop_per_dentist                            -3.699162e-02  3.699162e-02
# health__pop_per_primary_care_physician              6.943941e-04 -6.943941e-04
# heart_disease_mortality_per_100k                    3.713463e-05 -3.713463e-05
# Metro - Counties in metro areas of 1 million po...  2.787255e-17 -2.787255e-17
# Metro - Counties in metro areas of 250,000 to 1...  2.604839e-17 -2.604839e-17
# Metro - Counties in metro areas of fewer than 2...  9.806336e-19 -9.806336e-19
# Nonmetro - Completely rural or less than 2,500 ... -3.306861e-20  3.306861e-20
# Nonmetro - Completely rural or less than 2,500 ...  7.652612e-18 -7.652612e-18
# Nonmetro - Urban population of 2,500 to 19,999,... -2.229508e-17  2.229508e-17
# Nonmetro - Urban population of 2,500 to 19,999,...  9.011721e-18 -9.011721e-18
# Nonmetro - Urban population of 20,000 or more, ...  2.550809e-17 -2.550809e-17
# Nonmetro - Urban population of 20,000 or more, ... -1.894930e-18  1.894930e-18
# Large-in a metro area with at least 1 million r...  2.787255e-17 -2.787255e-17
# Micropolitan adjacent to a large metro area        -6.424167e-18  6.424167e-18
# Micropolitan adjacent to a small metro area        -5.063392e-18  5.063392e-18
# Micropolitan not adjacent to a metro area           8.281027e-18 -8.281027e-18
# Noncore adjacent to a large metro area             -2.172624e-17  2.172624e-17
# Noncore adjacent to a small metro and does not ...  4.319590e-18 -4.319590e-18
# Noncore adjacent to a small metro with town of ...  4.442573e-18 -4.442573e-18
# Noncore adjacent to micro area and contains a t... -4.383869e-18  4.383869e-18
# Noncore adjacent to micro area and does not con...  3.118461e-18 -3.118461e-18
# Noncore not adjacent to a metro/micro area and ...  1.667343e-17 -1.667343e-17
# Noncore not adjacent to a metro/micro area and ... -9.460499e-19  9.460499e-19
# Small-in a metro area with fewer than 1 million... -1.277260e-17  1.277260e-17
# Farm-dependent                                      3.250623e-17 -3.250623e-17
# Federal/State government-dependent                 -1.803550e-18  1.803550e-18
# Manufacturing-dependent                             3.698317e-18 -3.698317e-18
# Mining-dependent                                   -4.159772e-17  4.159772e-17
# Nonspecialized                                      5.040205e-18 -5.040205e-18
# Recreation                                         -2.486244e-18  2.486244e-18
# a                                                   1.000000e+00 -1.000000e+00
# b                                                  -1.000000e+00  1.000000e+00

# %%
df.isnull().sum()
# Out:
# econ__pct_civilian_labor                                                                              0
# econ__pct_unemployment                                                                                0
# econ__pct_uninsured_adults                                                                            0
# econ__pct_uninsured_children                                                                          0
# demo__pct_female                                                                                      0
# demo__pct_below_18_years_of_age                                                                       0
# demo__pct_aged_65_years_and_older                                                                     0
# demo__pct_hispanic                                                                                    0
# demo__pct_non_hispanic_african_american                                                               0
# demo__pct_non_hispanic_white                                                                          0
# demo__pct_american_indian_or_alaskan_native                                                           0
# demo__pct_asian                                                                                       0
# demo__pct_adults_less_than_a_high_school_diploma                                                      0
# demo__pct_adults_with_high_school_diploma                                                             0
# demo__pct_adults_with_some_college                                                                    0
# demo__pct_adults_bachelors_or_higher                                                                  0
# demo__birth_rate_per_1k                                                                               0
# demo__death_rate_per_1k                                                                               0
# health__pct_adult_obesity                                                                             0
# health__pct_adult_smoking                                                                             0
# health__pct_diabetes                                                                                  0
# health__pct_low_birthweight                                                                           0
# health__pct_excessive_drinking                                                                        0
# health__pct_physical_inacticity                                                                       0
# health__air_pollution_particulate_matter                                                              0
# health__homicides_per_100k                                                                            0
# health__motor_vehicle_crash_deaths_per_100k                                                           0
# health__pop_per_dentist                                                                               0
# health__pop_per_primary_care_physician                                                                0
# heart_disease_mortality_per_100k                                                                      0
# Metro - Counties in metro areas of 1 million population or more                                       0
# Metro - Counties in metro areas of 250,000 to 1 million population                                    0
# Metro - Counties in metro areas of fewer than 250,000 population                                      0
# Nonmetro - Completely rural or less than 2,500 urban population, adjacent to a metro area             0
# Nonmetro - Completely rural or less than 2,500 urban population, not adjacent to a metro area         0
# Nonmetro - Urban population of 2,500 to 19,999, adjacent to a metro area                              0
# Nonmetro - Urban population of 2,500 to 19,999, not adjacent to a metro area                          0
# Nonmetro - Urban population of 20,000 or more, adjacent to a metro area                               0
# Nonmetro - Urban population of 20,000 or more, not adjacent to a metro area                           0
# Large-in a metro area with at least 1 million residents or more                                       0
# Micropolitan adjacent to a large metro area                                                           0
# Micropolitan adjacent to a small metro area                                                           0
# Micropolitan not adjacent to a metro area                                                             0
# Noncore adjacent to a large metro area                                                                0
# Noncore adjacent to a small metro and does not contain a town of at least 2,500 residents             0
# Noncore adjacent to a small metro with town of at least 2,500 residents                               0
# Noncore adjacent to micro area and contains a town of 2,500-19,999 residents                          0
# Noncore adjacent to micro area and does not contain a town of at least 2,500 residents                0
# Noncore not adjacent to a metro/micro area and contains a town of 2,500  or more residents            0
# Noncore not adjacent to a metro/micro area and does not contain a town of at least 2,500 residents    0
# Small-in a metro area with fewer than 1 million residents                                             0
# Farm-dependent                                                                                        0
# Federal/State government-dependent                                                                    0
# Manufacturing-dependent                                                                               0
# Mining-dependent                                                                                      0
# Nonspecialized                                                                                        0
# Recreation                                                                                            0
# a                                                                                                     0
# b                                                                                                     0
# dtype: int64

# %% [markdown]
# Remove Outliers

# %%
corrmat = df.corr()
top_corr_features = corrmat.index[abs(corrmat["heart_disease_mortality_per_100k"]) > 0.5]
plt.figure(figsize=(15, 10))
g = sns.heatmap(df[top_corr_features].corr(), annot=True, cmap="RdYlGn")

# %%
features = ['econ__pct_civilian_labor','econ__pct_unemployment','econ__pct_uninsured_adults',
                'demo__pct_non_hispanic_african_american','demo__pct_adults_less_than_a_high_school_diploma',
                'demo__pct_adults_with_high_school_diploma','demo__pct_adults_with_some_college',
                'demo__pct_adults_bachelors_or_higher','demo__death_rate_per_1k','health__pct_adult_obesity',
                'health__pct_adult_smoking','health__pct_diabetes','health__pct_low_birthweight',
                'health__pct_physical_inacticity','health__homicides_per_100k','health__motor_vehicle_crash_deaths_per_100k']

# %% [markdown]
# Outliers

# %%
x = df.drop('heart_disease_mortality_per_100k',axis=1)
y = df['heart_disease_mortality_per_100k']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=0)

# %%
#df.drop(df[(df['demo__pct_adults_with_high_school_diploma']>0.35)].index,inplace=True)
plt.scatter(x_train['demo__pct_adults_with_high_school_diploma'],y_train)

# %%
sns.boxplot(x_train['demo__pct_adults_less_than_a_high_school_diploma'])

# %%
sns.violinplot(x_train['demo__pct_adults_less_than_a_high_school_diploma'])

# %%
count=0
for i in x_train['demo__pct_adults_less_than_a_high_school_diploma']:
    if i>0.35:
        count+=1
count
# Out:
# 23

# %%
plt.scatter(x_train['demo__pct_adults_bachelors_or_higher'],y_train)
df.drop(df[(df['demo__pct_adults_bachelors_or_higher']>0.7)&(df['heart_disease_mortality_per_100k']<200)].index,inplace=True)
plt.scatter(x_train['demo__pct_adults_bachelors_or_higher'],y_train)

# %%
sns.boxplot(x_train['demo__pct_adults_bachelors_or_higher'])

# %%
plt.scatter(x_train['health__pct_adult_obesity'],y_train)
df.drop(df[(df['health__pct_adult_obesity']>0.425)&(df['heart_disease_mortality_per_100k']<250)].index,inplace=True)
plt.scatter(x_train['health__pct_adult_obesity'],y_train)

# %%
# df.drop(df[(df['health__pct_adult_obesity']>0.425)&(df['heart_disease_mortality_per_100k']<250)].index,inplace=True)
# plt.scatter(df['health__pct_adult_obesity'],df['heart_disease_mortality_per_100k'])
plt.scatter(x_train['health__pct_diabetes'],y_train)

# %%
plt.scatter(x_train['health__pct_physical_inacticity'],y_train)

# %%
x = df.drop('heart_disease_mortality_per_100k',axis=1)
y = df['heart_disease_mortality_per_100k']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
def scaler(x_train,x_test):
    sc = RobustScaler()
    x_train = pd.DataFrame(sc.fit_transform(x_train))
    x_test = pd.DataFrame(sc.transform(x_test))
    return x_train,x_test

# %% [markdown]
# Features importance

# %%
model = ExtraTreesClassifier()
model.fit(x,y)
feat_importances = pd.Series(model.feature_importances_, index=x.columns)
feat_importances.nlargest(15).plot(kind='barh')
plt.figure(figsize=(15,8))
plt.show()

# %%
sns.distplot(y_train,fit=norm)
pl = plt.figure()
stats.probplot(y_train,plot=plt)
plt.show()

# %%
x_train,x_test = scaler(x_train,x_test)

# %%
model = RandomForestRegressor(n_estimators=500,criterion='mse')
model.fit(x_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=500)

# %%
model.score(x_test,y_test)
# Out:
# 0.7394981191024188

# %%
 kf = KFold(5, shuffle=True, random_state=42)

def rmse(y, y_pred):
    return np.sqrt(mean_squared_error(y, y_pred))

def rmsle_cv(model):
    rmse= np.sqrt(-cross_val_score(model, x.values, y.values, scoring="neg_mean_squared_error", cv = kf))
    return(rmse)

# %%
lgbm = LGBMRegressor(objective='regression',num_leaves=5,
                              learning_rate=0.01, n_estimators=5000,
                              max_bin = 55, bagging_fraction = 0.8,
                              bagging_freq = 5, feature_fraction = 0.2319,
                              feature_fraction_seed=9, bagging_seed=9,
                              min_data_in_leaf =6, min_sum_hessian_in_leaf = 11)

gbr = GradientBoostingRegressor(n_estimators=3000, learning_rate=0.05,
                                   max_depth=4, max_features='sqrt',
                                   min_samples_leaf=15, min_samples_split=10, 
                                   loss='huber')

rf = RandomForestRegressor(n_estimators=1200,
                          max_depth=15,
                          min_samples_split=5,
                          min_samples_leaf=5,
                          max_features=None,
                          oob_score=True)
                          


alphas_alt = [14.5, 14.6, 14.7, 14.8, 14.9, 15, 15.1, 15.2, 15.3, 15.4, 15.5]
alphas2 = [5e-05, 0.0001, 0.0002, 0.0003, 0.0004, 0.0005, 0.0006, 0.0007, 0.0008]
e_alphas = [0.0001, 0.0002, 0.0003, 0.0004, 0.0005, 0.0006, 0.0007]
e_l1ratio = [0.8, 0.85, 0.9, 0.95, 0.99, 1]

ridge = make_pipeline(RobustScaler(),
                      RidgeCV(alphas=alphas_alt, cv=kf))

lasso = make_pipeline(RobustScaler(),
                      LassoCV(max_iter=1e7, alphas=alphas2,
                              random_state=42, cv=kf))

elasticnet = make_pipeline(RobustScaler(),
                           ElasticNetCV(max_iter=1e7, alphas=e_alphas,
                                        cv=kf, l1_ratio=e_l1ratio))


stack_gen = StackingCVRegressor(regressors=(lgbm, gbr, rf,ridge,lasso,elasticnet),
                                meta_regressor=lgbm,
                                use_features_in_secondary=True,
                                cv = 5)

# %%
gbr.fit(x_train,y_train)
# Out:
# GradientBoostingRegressor(learning_rate=0.05, loss='huber', max_depth=4,
#                           max_features='sqrt', min_samples_leaf=15,
#                           min_samples_split=10, n_estimators=3000)

# %%
gbr.score(x_test,y_test)
# Out:
# 0.7875924715922975

# %%
rmsle_cv(gbr)
# Out:
# array([27.56642558, 27.79823042, 27.52641139, 25.05014537, 26.21986796])
